# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %%
alabama_subrank = pd.read_excel('2022 County Health Rankings Alabama Data - v1.xlsx', 2)
alabama_data = pd.read_excel('2022 County Health Rankings Alabama Data - v1.xlsx', 3)
alabama_data2 = pd.read_excel('2022 County Health Rankings Alabama Data - v1.xlsx', 4)

# %%
alabama_data2
# Out:
#    Unnamed: 0 Unnamed: 1  Unnamed: 2       COVID-19 age-adjusted mortality  \
# 0        FIPS      State      County  # deaths due to COVID-19 during 2020
# 1       01000    Alabama         NaN                                  6544
# 2       01001    Alabama     Autauga                                    55
# 3       01003    Alabama     Baldwin                                   165
# 4       01005    Alabama     Barbour                                    38
# ..        ...        ...         ...                                   ...
# 64      01125    Alabama  Tuscaloosa                                   252
# 65      01127    Alabama      Walker                                   165
# 66      01129    Alabama  Washington                                    24
# 67      01131    Alabama      Wilcox                                    22
# 68      01133    Alabama     Winston                                    37
#
# ...

# %%
new_ala_subrank = alabama_subrank[['Unnamed: 0','Unnamed: 1','Unnamed: 2','Quality of Life']]
new_ala_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
alabama_combined = alabama_data[['Unnamed: 1', 'Unnamed: 2','Unnamed: 155','Adult obesity', 'Access to exercise opportunities']]
alabama_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity', 'Access to exercise opportunities':' Percent Exercise'}, inplace = True)
new_bama = alabama_data2[['Unnamed: 1', 'Unnamed: 2', 'Population', 'Life expectancy','Median household income']]
new_bama.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Population':'Population', 'Life expectancy':'Life Expectancy', 'Median household income':'Median Household Income'}, inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\4120069918.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_ala_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\4120069918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alabama_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity', 'Access to exercise opportunities':' Percent Exercise'}, inplace = True)
# ...

# %%
alabama_half = pd.merge(new_ala_subrank, new_bama)

# %%
alabama_99 = pd.merge(alabama_half, alabama_combined)

# %%
alabama = alabama_99.drop(0)
alabama
# Out:
#     STCOU    State      County Quality of Life Population Life Expectancy  \
# 1   01000  Alabama         NaN             NaN    4921532       74.835949
# 2   01001  Alabama     Autauga       -0.469519      56145        76.58565
# 3   01003  Alabama     Baldwin       -0.823064     229287       77.724729
# 4   01005  Alabama     Barbour        0.538758      24589        72.86721
# 5   01007  Alabama        Bibb       -0.037711      22136       73.609363
# ..    ...      ...         ...             ...        ...             ...
# 64  01125  Alabama  Tuscaloosa       -0.333848     210758       75.826336
# 65  01127  Alabama      Walker        0.093553      63143       69.629257
# 66  01129  Alabama  Washington          0.3145      15976       75.287943
# 67  01131  Alabama      Wilcox        0.869915      10206       69.845386
# 68  01133  Alabama     Winston        0.155829      23508       74.823226
#
#    Median Household Income Percent Some College Adult Obesity  \
# ...

# %%
alaska_subrank = pd.read_excel('2022 County Health Rankings Alaska Data - v1.xlsx', 2)
alaska_data = pd.read_excel('2022 County Health Rankings Alaska Data - v1.xlsx', 3)
alaska_data2 = pd.read_excel('2022 County Health Rankings Alaska Data - v1.xlsx', 4)

# %%
new_alas_subrank = alaska_subrank[['Unnamed: 0','Unnamed: 1','Unnamed: 2','Quality of Life']]
new_alas_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
alaska_combined = alaska_data[['Unnamed: 1', 'Unnamed: 2','Unnamed: 155','Adult obesity','Access to exercise opportunities']]
alaska_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
new_alaska = alaska_data2[['Unnamed: 1', 'Unnamed: 2', 'Population', 'Life expectancy','Median household income']]
new_alaska.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Population':'Population', 'Life expectancy':'Life Expectancy', 'Median household income':'Median Household Income'}, inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\2301691963.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_alas_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\2301691963.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alaska_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
# ...

# %%
alaska_half = pd.merge(new_alas_subrank, new_alaska)

# %%
alaska_99 = pd.merge(alaska_half, alaska_combined)

# %%
alaska = alaska_99.drop(0)
alaska
# Out:
#     STCOU   State                 County Quality of Life Population  \
# 1   02000  Alaska                    NaN             NaN     731158
# 2   02013  Alaska         Aleutians East             NaN       3401
# 3   02016  Alaska         Aleutians West       -0.060267       5680
# 4   02020  Alaska              Anchorage       -0.136584     287095
# 5   02050  Alaska                 Bethel        0.695405      18437
# 6   02060  Alaska            Bristol Bay             NaN        788
# 7   02068  Alaska                 Denali             NaN       2081
# 8   02070  Alaska             Dillingham        0.284977       4833
# 9   02090  Alaska   Fairbanks North Star       -0.200446      95651
# 10  02100  Alaska                 Haines       -0.193933       2614
# 11  02105  Alaska          Hoonah-Angoon       -0.008565       2141
# 12  02110  Alaska                 Juneau       -0.389011      31849
# 13  02122  Alaska        Kenai Peninsula       -0.256026      59414
# ...

# %%
arizona_subrank = pd.read_excel('2022 County Health Rankings Arizona Data - v1.xlsx', 2)
arizona_data = pd.read_excel('2022 County Health Rankings Arizona Data - v1.xlsx', 3)
arizona_data2 = pd.read_excel('2022 County Health Rankings Arizona Data - v1.xlsx', 4)

# %%
new_ari_subrank = arizona_subrank[['Unnamed: 0','Unnamed: 1','Unnamed: 2','Quality of Life']]
new_ari_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
arizona_combined = arizona_data[['Unnamed: 1', 'Unnamed: 2','Unnamed: 155','Adult obesity','Access to exercise opportunities']]
arizona_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
new_arizona = arizona_data2[['Unnamed: 1', 'Unnamed: 2', 'Population', 'Life expectancy','Median household income']]
new_arizona.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Population':'Population', 'Life expectancy':'Life Expectancy', 'Median household income':'Median Household Income'}, inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\549565211.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_ari_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\549565211.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   arizona_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
# ...

# %%
arizona_half = pd.merge(new_ari_subrank, new_arizona)

# %%
arizona_99 = pd.merge(arizona_half, arizona_combined)

# %%
arizona = arizona_99.drop(0)
arizona
# Out:
#     STCOU    State      County Quality of Life Population Life Expectancy  \
# 1   04000  Arizona         NaN             NaN    7421401       79.061023
# 2   04001  Arizona      Apache        0.786613      71875       70.134961
# 3   04003  Arizona     Cochise       -0.059317     127450       78.247948
# 4   04005  Arizona    Coconino       -0.086696     142481       77.965251
# 5   04007  Arizona        Gila        0.520551      54303       72.677026
# 6   04009  Arizona      Graham        0.132656      39211       76.968322
# 7   04011  Arizona    Greenlee       -0.141698       9341       79.922212
# 8   04012  Arizona      La Paz       -0.046988      21480        77.70255
# 9   04013  Arizona    Maricopa       -0.384237    4579081       79.637281
# 10  04015  Arizona      Mohave       -0.111565     217206       75.467161
# 11  04017  Arizona      Navajo        0.636973     112112       71.398138
# 12  04019  Arizona        Pima       -0.251428    1061175       78.472346
# ...

# %%
arkansas_subrank = pd.read_excel('2022 County Health Rankings Arkansas Data - v1.xlsx', 2)
arkansas_data = pd.read_excel('2022 County Health Rankings Arkansas Data - v1.xlsx', 3)
arkansas_data2 = pd.read_excel('2022 County Health Rankings Arkansas Data - v1.xlsx', 4)

# %%
new_ark_subrank = arkansas_subrank[['Unnamed: 0','Unnamed: 1','Unnamed: 2','Quality of Life']]
new_ark_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
arkansas_combined = arkansas_data[['Unnamed: 1', 'Unnamed: 2','Unnamed: 155','Adult obesity','Access to exercise opportunities']]
arkansas_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
new_arkansas = arkansas_data2[['Unnamed: 1', 'Unnamed: 2', 'Population', 'Life expectancy','Median household income']]
new_arkansas.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Population':'Population', 'Life expectancy':'Life Expectancy', 'Median household income':'Median Household Income'}, inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\253544629.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_ark_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\253544629.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   arkansas_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
# ...

# %%
arkansas_half = pd.merge(new_ark_subrank, new_arkansas)

# %%
arkansas_99 = pd.merge(arkansas_half, arkansas_combined)

# %%
arkansas = arkansas_99.drop(0)
arkansas
# Out:
#     STCOU     State      County Quality of Life Population Life Expectancy  \
# 1   05000  Arkansas         NaN             NaN    3030522       75.488385
# 2   05001  Arkansas    Arkansas        0.081614      17383       72.947023
# 3   05003  Arkansas      Ashley        0.260875      19339        73.81421
# 4   05005  Arkansas      Baxter       -0.534536      42242       76.058275
# 5   05007  Arkansas      Benton       -0.976985     288774       79.471534
# ..    ...       ...         ...             ...        ...             ...
# 72  05141  Arkansas   Van Buren       -0.002856      16541       76.962576
# 73  05143  Arkansas  Washington       -0.613011     243216       77.984422
# 74  05145  Arkansas       White       -0.256525      78729       75.157789
# 75  05147  Arkansas    Woodruff        0.126315       6264       72.516375
# 76  05149  Arkansas        Yell        0.062396      21181        75.22529
#
#    Median Household Income Percent Some College Adult Obesity  \
# ...

# %%
california_subrank = pd.read_excel('2022 County Health Rankings California Data - v1.xlsx', 2)
california_data = pd.read_excel('2022 County Health Rankings California Data - v1.xlsx', 3)
california_data2 = pd.read_excel('2022 County Health Rankings California Data - v1.xlsx', 4)

# %%
new_ca_subrank = california_subrank[['Unnamed: 0','Unnamed: 1','Unnamed: 2','Quality of Life']]
new_ca_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
california_combined = california_data[['Unnamed: 1', 'Unnamed: 2','Unnamed: 155','Adult obesity','Access to exercise opportunities']]
california_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
new_california = california_data2[['Unnamed: 1', 'Unnamed: 2', 'Population', 'Life expectancy','Median household income']]
new_california.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Population':'Population', 'Life expectancy':'Life Expectancy', 'Median household income':'Median Household Income'}, inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\3719995241.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_ca_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\3719995241.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   california_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
# ...

# %%
california_half = pd.merge(new_ca_subrank, new_california)
california_99 = pd.merge(california_half, california_combined)
california = california_99.drop(0)
california
# Out:
#     STCOU       State           County Quality of Life Population  \
# 1   06000  California              NaN             NaN   39368078
# 2   06001  California          Alameda       -0.340775    1662323
# 3   06003  California           Alpine        0.160808       1119
# 4   06005  California           Amador       -0.226803      40083
# 5   06007  California            Butte       -0.055954     212744
# 6   06009  California        Calaveras       -0.083928      46308
# 7   06011  California           Colusa        0.033333      21558
# 8   06013  California     Contra Costa       -0.309885    1152333
# 9   06015  California        Del Norte        0.202348      27968
# 10  06017  California        El Dorado       -0.278788     192925
# 11  06019  California           Fresno        0.479223    1000918
# 12  06021  California            Glenn        0.148482      28283
# 13  06023  California         Humboldt       -0.013282     134977
# ...

# %%
colorado_subrank = pd.read_excel('2022 County Health Rankings Colorado Data - v1.xlsx', 2)
colorado_data = pd.read_excel('2022 County Health Rankings Colorado Data - v1.xlsx', 3)
colorado_data2 = pd.read_excel('2022 County Health Rankings Colorado Data - v1.xlsx', 4)

# %%
new_col_subrank = colorado_subrank[['Unnamed: 0','Unnamed: 1','Unnamed: 2','Quality of Life']]
new_col_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
colorado_combined = colorado_data[['Unnamed: 1', 'Unnamed: 2','Unnamed: 155','Adult obesity','Access to exercise opportunities']]
colorado_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
new_colorado = colorado_data2[['Unnamed: 1', 'Unnamed: 2', 'Population', 'Life expectancy','Median household income']]
new_colorado.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Population':'Population', 'Life expectancy':'Life Expectancy', 'Median household income':'Median Household Income'}, inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\2688729210.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_col_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\2688729210.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   colorado_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
# ...

# %%
colorado_half = pd.merge(new_col_subrank, new_colorado)
colorado_99 = pd.merge(colorado_half, colorado_combined)
colorado = colorado_99.drop(0)
colorado
# Out:
#     STCOU     State      County Quality of Life Population Life Expectancy  \
# 1   08000  Colorado         NaN             NaN    5807719        79.97719
# 2   08001  Colorado       Adams        -0.05458     519883       78.634829
# 3   08003  Colorado     Alamosa        0.453693      16180       75.142668
# 4   08005  Colorado    Arapahoe       -0.280499     657452       80.620197
# 5   08007  Colorado   Archuleta       -0.290733      14196       82.572998
# ..    ...       ...         ...             ...        ...             ...
# 61  08117  Colorado      Summit       -0.121919      30631       93.526868
# 62  08119  Colorado      Teller        0.049765      25529       81.462736
# 63  08121  Colorado  Washington        -0.01673       4875       76.715879
# 64  08123  Colorado        Weld       -0.166372     333983       80.343726
# 65  08125  Colorado        Yuma       -0.054111      10047       79.719435
#
#    Median Household Income Percent Some College Adult Obesity  \
# ...

# %%
connecticut_subrank = pd.read_excel('2022 County Health Rankings Connecticut Data - v1.xlsx', 2)
connecticut_data = pd.read_excel('2022 County Health Rankings Connecticut Data - v1.xlsx', 3)
connecticut_data2 = pd.read_excel('2022 County Health Rankings Connecticut Data - v1.xlsx', 4)

# %%
new_conn_subrank = connecticut_subrank[['Unnamed: 0','Unnamed: 1','Unnamed: 2','Quality of Life']]
new_conn_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
connecticut_combined = connecticut_data[['Unnamed: 1', 'Unnamed: 2','Unnamed: 155','Adult obesity','Access to exercise opportunities']]
connecticut_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
new_connecticut = connecticut_data2[['Unnamed: 1', 'Unnamed: 2', 'Population', 'Life expectancy','Median household income']]
new_connecticut.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Population':'Population', 'Life expectancy':'Life Expectancy', 'Median household income':'Median Household Income'}, inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\413724086.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_conn_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\413724086.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   connecticut_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
# ...

# %%
connecticut_half = pd.merge(new_conn_subrank, new_connecticut)
connecticut_99 = pd.merge(connecticut_half, connecticut_combined)
connecticut = connecticut_99.drop(0)
connecticut
# Out:
#    STCOU        State      County Quality of Life Population Life Expectancy  \
# 1  09000  Connecticut         NaN             NaN    3557006       80.107442
# 2  09001  Connecticut   Fairfield       -0.328257     942426       82.057347
# 3  09003  Connecticut    Hartford        0.327234     889226        79.42689
# 4  09005  Connecticut  Litchfield       -0.378234     179610       79.190826
# 5  09007  Connecticut   Middlesex       -0.429965     161657       80.812817
# 6  09009  Connecticut   New Haven        0.368858     851948       79.189856
# 7  09011  Connecticut  New London       -0.030903     264999       79.454798
# 8  09013  Connecticut     Tolland       -0.229336     150600       81.323431
# 9  09015  Connecticut     Windham        0.700603     116540        78.00408
#
#   Median Household Income Percent Some College Adult Obesity  Percent Exercise
# 1                   79723            70.118412          29.1         88.753327
# ...

# %%
delaware_subrank = pd.read_excel('2022 County Health Rankings Delaware Data - v1.xlsx', 2)
delaware_data = pd.read_excel('2022 County Health Rankings Delaware Data - v1.xlsx', 3)
delaware_data2 = pd.read_excel('2022 County Health Rankings Delaware Data - v1.xlsx', 4)

# %%
new_del_subrank = delaware_subrank[['Unnamed: 0','Unnamed: 1','Unnamed: 2','Quality of Life']]
new_del_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
delaware_combined = delaware_data[['Unnamed: 1', 'Unnamed: 2','Unnamed: 155','Adult obesity','Access to exercise opportunities']]
delaware_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
new_delaware = delaware_data2[['Unnamed: 1', 'Unnamed: 2', 'Population', 'Life expectancy','Median household income']]
new_delaware.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Population':'Population', 'Life expectancy':'Life Expectancy', 'Median household income':'Median Household Income'}, inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\314298214.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_del_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\314298214.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delaware_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
# ...

# %%
delaware_half = pd.merge(new_del_subrank, new_delaware)
delaware_99 = pd.merge(delaware_half, delaware_combined)
delaware = delaware_99.drop(0)
delaware
# Out:
#    STCOU     State      County Quality of Life Population Life Expectancy  \
# 1  10000  Delaware         NaN             NaN     986809       78.009491
# 2  10001  Delaware        Kent        0.427349     183643       77.106527
# 3  10003  Delaware  New Castle       -0.221591     561531       77.935484
# 4  10005  Delaware      Sussex       -0.205758     241635       78.411411
#
#   Median Household Income Percent Some College Adult Obesity  Percent Exercise
# 1                   71335            62.188875          34.2          79.87959
# 2                   61538            60.658567          41.2         51.391781
# 3                   75145            64.741682            33         94.171732
# 4                   69829            55.256249          35.3          64.29633

# %%
florida_subrank = pd.read_excel('2022 County Health Rankings Florida Data - v1.xlsx', 2)
florida_data = pd.read_excel('2022 County Health Rankings Florida Data - v1.xlsx', 3)
florida_data2 = pd.read_excel('2022 County Health Rankings Florida Data - v1.xlsx', 4)

# %%
new_flo_subrank = florida_subrank[['Unnamed: 0','Unnamed: 1','Unnamed: 2','Quality of Life']]
new_flo_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
florida_combined = florida_data[['Unnamed: 1', 'Unnamed: 2','Unnamed: 155','Adult obesity','Access to exercise opportunities']]
florida_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
new_florida = florida_data2[['Unnamed: 1', 'Unnamed: 2', 'Population', 'Life expectancy','Median household income']]
new_florida.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Population':'Population', 'Life expectancy':'Life Expectancy', 'Median household income':'Median Household Income'}, inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\3250552010.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_flo_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\3250552010.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   florida_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
# ...

# %%
florida_half = pd.merge(new_flo_subrank, new_florida)
florida_99 = pd.merge(florida_half, florida_combined)
florida = florida_99.drop(0)
florida
# Out:
#     STCOU    State      County Quality of Life Population Life Expectancy  \
# 1   12000  Florida         NaN             NaN   21733312       79.692946
# 2   12001  Florida     Alachua        0.030735     271218       78.600527
# 3   12003  Florida       Baker        0.237868      29566       75.486282
# 4   12005  Florida         Bay       -0.158716     171322       76.065171
# 5   12007  Florida    Bradford        0.609542      28593       75.494264
# ..    ...      ...         ...             ...        ...             ...
# 64  12125  Florida       Union         0.47501      15182       67.238936
# 65  12127  Florida     Volusia       -0.138197     561497       76.562362
# 66  12129  Florida     Wakulla       -0.141809      34319        76.11615
# 67  12131  Florida      Walton       -0.288035      76648       78.420628
# 68  12133  Florida  Washington        0.464533      25932       72.782737
#
#    Median Household Income Percent Some College Adult Obesity  \
# ...

# %%
georgia_subrank = pd.read_excel('2022 County Health Rankings Georgia Data - v1.xlsx', 2)
georgia_data = pd.read_excel('2022 County Health Rankings Georgia Data - v1.xlsx', 3)
georgia_data2 = pd.read_excel('2022 County Health Rankings Georgia Data - v1.xlsx', 4)

# %%
new_geo_subrank = georgia_subrank[['Unnamed: 0','Unnamed: 1','Unnamed: 2','Quality of Life']]
new_geo_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
georgia_combined = georgia_data[['Unnamed: 1', 'Unnamed: 2','Unnamed: 155','Adult obesity','Access to exercise opportunities']]
georgia_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
new_georgia = georgia_data2[['Unnamed: 1', 'Unnamed: 2', 'Population', 'Life expectancy','Median household income']]
new_georgia.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Population':'Population', 'Life expectancy':'Life Expectancy', 'Median household income':'Median Household Income'}, inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\3902176058.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_geo_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\3902176058.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   georgia_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
# ...

# %%
georgia_half = pd.merge(new_geo_subrank, new_georgia)
georgia_99 = pd.merge(georgia_half, georgia_combined)
georgia = georgia_99.drop(0)
georgia
# Out:
#      STCOU    State     County Quality of Life Population Life Expectancy  \
# 1    13000  Georgia        NaN             NaN   10710017       77.309261
# 2    13001  Georgia    Appling        0.286302      18325        73.87281
# 3    13003  Georgia   Atkinson        0.213578       8393       73.076566
# 4    13005  Georgia      Bacon        0.277557      11036        72.45924
# 5    13007  Georgia      Baker        0.063455       2971       79.801263
# ..     ...      ...        ...             ...        ...             ...
# 156  13313  Georgia  Whitfield       -0.220043     103837       77.172717
# 157  13315  Georgia     Wilcox        0.320526       8502       75.170123
# 158  13317  Georgia     Wilkes        0.169948       9694        75.21437
# 159  13319  Georgia  Wilkinson        0.373016       8812       73.225832
# 160  13321  Georgia      Worth        0.345965      19972       74.163735
#
#     Median Household Income Percent Some College Adult Obesity  \
# ...

# %%
hawaii_subrank = pd.read_excel('2022 County Health Rankings Hawaii Data - v1.xlsx', 2)
hawaii_data = pd.read_excel('2022 County Health Rankings Hawaii Data - v1.xlsx', 3)
hawaii_data2 = pd.read_excel('2022 County Health Rankings Hawaii Data - v1.xlsx', 4)

# %%
new_haw_subrank = hawaii_subrank[['Unnamed: 0','Unnamed: 1','Unnamed: 2','Quality of Life']]
new_haw_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
hawaii_combined = hawaii_data[['Unnamed: 1', 'Unnamed: 2','Unnamed: 155','Adult obesity','Access to exercise opportunities']]
hawaii_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
new_hawaii = hawaii_data2[['Unnamed: 1', 'Unnamed: 2', 'Population', 'Life expectancy','Median household income']]
new_hawaii.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Population':'Population', 'Life expectancy':'Life Expectancy', 'Median household income':'Median Household Income'}, inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\4042585419.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_haw_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\4042585419.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hawaii_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
# ...

# %%
hawaii_half = pd.merge(new_haw_subrank, new_hawaii)
hawaii_99 = pd.merge(hawaii_half, hawaii_combined)
hawaii = hawaii_99.drop(0)
hawaii
# Out:
#    STCOU   State    County Quality of Life Population Life Expectancy  \
# 1  15000  Hawaii       NaN             NaN    1407006       82.258268
# 2  15001  Hawaii    Hawaii        0.611951     203340       80.969821
# 3  15003  Hawaii  Honolulu       -0.179389     963826       82.377942
# 4  15005  Hawaii   Kalawao             NaN         87             NaN
# 5  15007  Hawaii     Kauai       -0.075636      71851       82.347675
# 6  15009  Hawaii      Maui       -0.356927     167902        82.89581
#
#   Median Household Income Percent Some College Adult Obesity  Percent Exercise
# 1                   86878            69.015203          25.5         90.015372
# 2                   70313            60.101063          25.2         66.374359
# 3                   89584            72.527376          25.4         95.054694
# 4                     NaN            67.078189          26.7               100
# 5                   80517            61.435078          24.9         90.752858
# ...

# %%
idaho_subrank = pd.read_excel('2022 County Health Rankings Idaho Data - v1.xlsx', 2)
idaho_data = pd.read_excel('2022 County Health Rankings Idaho Data - v1.xlsx', 3)
idaho_data2 = pd.read_excel('2022 County Health Rankings Idaho Data - v1.xlsx', 4)

# %%
new_ida_subrank = idaho_subrank[['Unnamed: 0','Unnamed: 1','Unnamed: 2','Quality of Life']]
new_ida_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
idaho_combined = idaho_data[['Unnamed: 1', 'Unnamed: 2','Unnamed: 155','Adult obesity','Access to exercise opportunities']]
idaho_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
new_idaho = idaho_data2[['Unnamed: 1', 'Unnamed: 2', 'Population', 'Life expectancy','Median household income']]
new_idaho.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Population':'Population', 'Life expectancy':'Life Expectancy', 'Median household income':'Median Household Income'}, inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\1931110833.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_ida_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\1931110833.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   idaho_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
# ...

# %%
idaho_half = pd.merge(new_ida_subrank, new_idaho)
idaho_99 = pd.merge(idaho_half, idaho_combined)
idaho = idaho_99.drop(0)
idaho
# Out:
#     STCOU  State      County Quality of Life Population Life Expectancy  \
# 1   16000  Idaho         NaN             NaN    1826913       79.185471
# 2   16001  Idaho         Ada        -0.69904     494399       80.811283
# 3   16003  Idaho       Adams        0.358905       4447       80.905483
# 4   16005  Idaho     Bannock        0.128753      88795       76.942463
# 5   16007  Idaho   Bear Lake        0.288773       6143       78.291622
# 6   16009  Idaho     Benewah        0.341172       9430       74.750534
# 7   16011  Idaho     Bingham        0.118704      47202       76.656259
# 8   16013  Idaho      Blaine       -0.582795      23426       85.245953
# 9   16015  Idaho       Boise       -0.383754       8065       81.793218
# 10  16017  Idaho      Bonner       -0.198037      46817       79.626378
# 11  16019  Idaho  Bonneville       -0.186032     122134       77.185665
# 12  16021  Idaho    Boundary       -0.252698      12656       79.487004
# ...

# %%
illinois_subrank = pd.read_excel('2022 County Health Rankings Illinois Data - v1.xlsx', 2)
illinois_data = pd.read_excel('2022 County Health Rankings Illinois Data - v1.xlsx', 3)
illinois_data2 = pd.read_excel('2022 County Health Rankings Illinois Data - v1.xlsx', 4)

# %%
new_ill_subrank = illinois_subrank[['Unnamed: 0','Unnamed: 1','Unnamed: 2','Quality of Life']]
new_ill_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
illinois_combined = illinois_data[['Unnamed: 1', 'Unnamed: 2','Unnamed: 155','Adult obesity','Access to exercise opportunities']]
illinois_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
new_illinois = illinois_data2[['Unnamed: 1', 'Unnamed: 2', 'Population', 'Life expectancy','Median household income']]
new_illinois.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Population':'Population', 'Life expectancy':'Life Expectancy', 'Median household income':'Median Household Income'}, inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\3294547052.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_ill_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\3294547052.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   illinois_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
# ...

# %%
illinois_half = pd.merge(new_ill_subrank, new_illinois)
illinois_99 = pd.merge(illinois_half, illinois_combined)
illinois = illinois_99.drop(0)
illinois
# Out:
#      STCOU     State      County Quality of Life Population Life Expectancy  \
# 1    17000  Illinois         NaN             NaN   12587530       78.615342
# 2    17001  Illinois       Adams        -0.10857      64783        77.83136
# 3    17003  Illinois   Alexander        0.887263       5497       70.483626
# 4    17005  Illinois        Bond       -0.075943      16262       78.389115
# 5    17007  Illinois       Boone       -0.331091      52777       79.254655
# ..     ...       ...         ...             ...        ...             ...
# 99   17195  Illinois   Whiteside       -0.377573      54656       77.605918
# 100  17197  Illinois        Will       -0.606105     688726       79.201645
# 101  17199  Illinois  Williamson        0.106256      66415        77.28375
# 102  17201  Illinois   Winnebago        0.271299     281295        76.16637
# 103  17203  Illinois    Woodford       -0.755462      38091       79.133714
#
# ...

# %%
indiana_subrank = pd.read_excel('2022 County Health Rankings Indiana Data - v1.xlsx', 2)
indiana_data = pd.read_excel('2022 County Health Rankings Indiana Data - v1.xlsx', 3)
indiana_data2 = pd.read_excel('2022 County Health Rankings Indiana Data - v1.xlsx', 4)

# %%
new_ind_subrank = indiana_subrank[['Unnamed: 0','Unnamed: 1','Unnamed: 2','Quality of Life']]
new_ind_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
indiana_combined = indiana_data[['Unnamed: 1', 'Unnamed: 2','Unnamed: 155','Adult obesity','Access to exercise opportunities']]
indiana_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
new_indiana = indiana_data2[['Unnamed: 1', 'Unnamed: 2', 'Population', 'Life expectancy','Median household income']]
new_indiana.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Population':'Population', 'Life expectancy':'Life Expectancy', 'Median household income':'Median Household Income'}, inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\4238046021.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_ind_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\4238046021.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   indiana_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
# ...

# %%
indiana_half = pd.merge(new_ind_subrank, new_indiana)
indiana_99 = pd.merge(indiana_half, indiana_combined)
indiana = indiana_99.drop(0)
indiana
# Out:
#     STCOU    State       County Quality of Life Population Life Expectancy  \
# 1   18000  Indiana          NaN             NaN    6754953       76.514893
# 2   18001  Indiana        Adams        0.207644      35839       77.917169
# 3   18003  Indiana        Allen        0.048466     382187       76.647795
# 4   18005  Indiana  Bartholomew       -0.398707      84447       77.976867
# 5   18007  Indiana       Benton        0.001018       8741       76.768566
# ..    ...      ...          ...             ...        ...             ...
# 89  18175  Indiana   Washington        0.119887      28213       75.146774
# 90  18177  Indiana        Wayne        0.442362      65778       72.941824
# 91  18179  Indiana        Wells       -0.189534      28142       77.248031
# 92  18181  Indiana        White       -0.230676      24165       75.759883
# 93  18183  Indiana      Whitley       -0.229983      34378       78.831932
#
#    Median Household Income Percent Some College Adult Obesity  \
# ...

# %%
iowa_subrank = pd.read_excel('2022 County Health Rankings Iowa Data - v1.xlsx', 2)
iowa_data = pd.read_excel('2022 County Health Rankings Iowa Data - v1.xlsx', 3)
iowa_data2 = pd.read_excel('2022 County Health Rankings Iowa Data - v1.xlsx', 4)

# %%
new_iowa_subrank = iowa_subrank[['Unnamed: 0','Unnamed: 1','Unnamed: 2','Quality of Life']]
new_iowa_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
iowa_combined = iowa_data[['Unnamed: 1', 'Unnamed: 2','Unnamed: 155','Adult obesity','Access to exercise opportunities']]
iowa_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
new_iowa = iowa_data2[['Unnamed: 1', 'Unnamed: 2', 'Population', 'Life expectancy','Median household income']]
new_iowa.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Population':'Population', 'Life expectancy':'Life Expectancy', 'Median household income':'Median Household Income'}, inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\4080473511.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_iowa_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\4080473511.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iowa_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
# ...

# %%
iowa_half = pd.merge(new_iowa_subrank, new_iowa)
iowa_99 = pd.merge(iowa_half, iowa_combined)
iowa = iowa_99.drop(0)
iowa
# Out:
#      STCOU State      County Quality of Life Population Life Expectancy  \
# 1    19000  Iowa         NaN             NaN    3163561       78.743465
# 2    19001  Iowa       Adair       -0.143509       7059       78.168987
# 3    19003  Iowa       Adams         -0.3828       3588       79.746653
# 4    19005  Iowa   Allamakee       -0.082269      13642       77.640865
# 5    19007  Iowa   Appanoose        0.892733      12430       76.867942
# ..     ...   ...         ...             ...        ...             ...
# 96   19189  Iowa   Winnebago       -0.016775      10277       79.032842
# 97   19191  Iowa  Winneshiek       -0.602037      19862       83.471085
# 98   19193  Iowa    Woodbury        0.208552     103138       76.265187
# 99   19195  Iowa       Worth        0.021608       7359       80.104585
# 100  19197  Iowa      Wright        -0.00806      12416       78.825302
#
#     Median Household Income Percent Some College Adult Obesity  \
# ...

# %%
kansas_subrank = pd.read_excel('2022 County Health Rankings Kansas Data - v1.xlsx', 2)
kansas_data = pd.read_excel('2022 County Health Rankings Kansas Data - v1.xlsx', 3)
kansas_data2 = pd.read_excel('2022 County Health Rankings Kansas Data - v1.xlsx', 4)

# %%
new_kansas_subrank = kansas_subrank[['Unnamed: 0','Unnamed: 1','Unnamed: 2','Quality of Life']]
new_kansas_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
kansas_combined = kansas_data[['Unnamed: 1', 'Unnamed: 2','Unnamed: 155','Adult obesity','Access to exercise opportunities']]
kansas_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
new_kansas = kansas_data2[['Unnamed: 1', 'Unnamed: 2', 'Population', 'Life expectancy','Median household income']]
new_kansas.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Population':'Population', 'Life expectancy':'Life Expectancy', 'Median household income':'Median Household Income'}, inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\3927764806.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_kansas_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\3927764806.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kansas_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
# ...

# %%
kansas_half = pd.merge(new_kansas_subrank, new_kansas)
kansas_99 = pd.merge(kansas_half, kansas_combined)
kansas = kansas_99.drop(0)
kansas
# Out:
#      STCOU   State      County Quality of Life Population Life Expectancy  \
# 1    20000  Kansas         NaN             NaN    2913805       77.810874
# 2    20001  Kansas       Allen        0.347029      12399       76.299846
# 3    20003  Kansas    Anderson        0.138419       7949       76.498517
# 4    20005  Kansas    Atchison        0.072999      16015       77.676637
# 5    20007  Kansas      Barber        0.046114       4358       75.518934
# ..     ...     ...         ...             ...        ...             ...
# 102  20201  Kansas  Washington        0.059877       5427       80.325503
# 103  20203  Kansas     Wichita       -0.315714       2074       74.862458
# 104  20205  Kansas      Wilson        0.328948       8362        75.61225
# 105  20207  Kansas     Woodson        0.290517       3015       76.599285
# 106  20209  Kansas   Wyandotte         0.82562     165265        74.65877
#
#     Median Household Income Percent Some College Adult Obesity  \
# ...

# %%
kentucky_subrank = pd.read_excel('2022 County Health Rankings Kentucky Data - v1.xlsx', 2)
kentucky_data = pd.read_excel('2022 County Health Rankings Kentucky Data - v1.xlsx', 3)
kentucky_data2 = pd.read_excel('2022 County Health Rankings Kentucky Data - v1.xlsx', 4)

# %%
new_kentucky_subrank = kentucky_subrank[['Unnamed: 0','Unnamed: 1','Unnamed: 2','Quality of Life']]
new_kentucky_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
kentucky_combined = kentucky_data[['Unnamed: 1', 'Unnamed: 2','Unnamed: 155','Adult obesity','Access to exercise opportunities']]
kentucky_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
new_kentucky = kentucky_data2[['Unnamed: 1', 'Unnamed: 2', 'Population', 'Life expectancy','Median household income']]
new_kentucky.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Population':'Population', 'Life expectancy':'Life Expectancy', 'Median household income':'Median Household Income'}, inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\1551640159.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_kentucky_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\1551640159.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kentucky_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
# ...

# %%
kentucky_half = pd.merge(new_kentucky_subrank, new_kentucky)
kentucky_99 = pd.merge(kentucky_half, kentucky_combined)
kentucky = kentucky_99.drop(0)
kentucky
# Out:
#      STCOU     State    County Quality of Life Population Life Expectancy  \
# 1    21000  Kentucky       NaN             NaN    4477251       75.081765
# 2    21001  Kentucky     Adair        0.050222      19555       74.732248
# 3    21003  Kentucky     Allen        0.246651      21303       74.731033
# 4    21005  Kentucky  Anderson       -0.459468      22833       75.368695
# 5    21007  Kentucky   Ballard       -0.247259       7769       76.500035
# ..     ...       ...       ...             ...        ...             ...
# 117  21231  Kentucky     Wayne        0.219253      20209       75.759005
# 118  21233  Kentucky   Webster        0.427558      12923       74.118069
# 119  21235  Kentucky   Whitley        0.346145      36451       70.890733
# 120  21237  Kentucky     Wolfe        0.660249       7106       67.960587
# 121  21239  Kentucky  Woodford       -0.674633      26765       77.603074
#
#     Median Household Income Percent Some College Adult Obesity  \
# ...

# %%
louisiana_subrank = pd.read_excel('2022 County Health Rankings Louisiana Data - v1.xlsx', 2)
louisiana_data = pd.read_excel('2022 County Health Rankings Louisiana Data - v1.xlsx', 3)
louisiana_data2 = pd.read_excel('2022 County Health Rankings Louisiana Data - v1.xlsx', 4)

# %%
new_louisiana_subrank = louisiana_subrank[['Unnamed: 0','Unnamed: 1','Unnamed: 2','Quality of Life']]
new_louisiana_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
louisiana_combined = louisiana_data[['Unnamed: 1', 'Unnamed: 2','Unnamed: 155','Adult obesity','Access to exercise opportunities']]
louisiana_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
new_louisiana = louisiana_data2[['Unnamed: 1', 'Unnamed: 2', 'Population', 'Life expectancy','Median household income']]
new_louisiana.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Population':'Population', 'Life expectancy':'Life Expectancy', 'Median household income':'Median Household Income'}, inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\25461114.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_louisiana_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\25461114.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   louisiana_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
# ...

# %%
louisiana_half = pd.merge(new_louisiana_subrank, new_louisiana)
louisiana_99 = pd.merge(louisiana_half, louisiana_combined)
louisiana = louisiana_99.drop(0)
louisiana
# Out:
#     STCOU      State            County Quality of Life Population  \
# 1   22000  Louisiana               NaN             NaN    4645318
# 2   22001  Louisiana            Acadia       -0.084219      61918
# 3   22003  Louisiana             Allen        -0.34281      25440
# 4   22005  Louisiana         Ascension       -0.758001     128665
# 5   22007  Louisiana        Assumption        0.190035      21621
# ..    ...        ...               ...             ...        ...
# 61  22119  Louisiana           Webster        0.463064      37943
# 62  22121  Louisiana  West Baton Rouge       -0.375091      26792
# 63  22123  Louisiana      West Carroll        -0.01374      10646
# 64  22125  Louisiana    West Feliciana       -0.701234      15465
# 65  22127  Louisiana              Winn        0.051034      13839
#
#    Life Expectancy Median Household Income Percent Some College Adult Obesity  \
# 1        75.223197                   51730            57.806324          36.2
# ...

# %%
maine_subrank = pd.read_excel('2022 County Health Rankings Maine Data - v1.xlsx', 2)
maine_data = pd.read_excel('2022 County Health Rankings Maine Data - v1.xlsx', 3)
maine_data2 = pd.read_excel('2022 County Health Rankings Maine Data - v1.xlsx', 4)

# %%
new_maine_subrank = maine_subrank[['Unnamed: 0','Unnamed: 1','Unnamed: 2','Quality of Life']]
new_maine_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
maine_combined = maine_data[['Unnamed: 1', 'Unnamed: 2','Unnamed: 155','Adult obesity','Access to exercise opportunities']]
maine_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
new_maine = maine_data2[['Unnamed: 1', 'Unnamed: 2', 'Population', 'Life expectancy','Median household income']]
new_maine.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Population':'Population', 'Life expectancy':'Life Expectancy', 'Median household income':'Median Household Income'}, inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\178235122.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_maine_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\178235122.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   maine_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
# ...

# %%
maine_half = pd.merge(new_maine_subrank, new_maine)
maine_99 = pd.merge(maine_half, maine_combined)
maine = maine_99.drop(0)
maine
# Out:
#     STCOU  State        County Quality of Life Population Life Expectancy  \
# 1   23000  Maine           NaN             NaN    1350141       78.562332
# 2   23001  Maine  Androscoggin          0.1863     108547       76.807512
# 3   23003  Maine     Aroostook        0.349717      66804       78.313734
# 4   23005  Maine    Cumberland       -0.796439     298111       80.169038
# 5   23007  Maine      Franklin        0.234241      29986       78.158969
# 6   23009  Maine       Hancock       -0.251651      55088       79.493682
# 7   23011  Maine      Kennebec       -0.192618     122955       77.901902
# 8   23013  Maine          Knox        -0.50699      39951       79.287423
# 9   23015  Maine       Lincoln          0.3176      34775       80.222855
# 10  23017  Maine        Oxford        0.183333      58132       77.426504
# 11  23019  Maine     Penobscot        0.040521     151655       77.118999
# 12  23021  Maine   Piscataquis        0.636661      16996       77.167747
# ...

# %%
maryland_subrank = pd.read_excel('2022 County Health Rankings Maryland Data - v1.xlsx', 2)
maryland_data = pd.read_excel('2022 County Health Rankings Maryland Data - v1.xlsx', 3)
maryland_data2 = pd.read_excel('2022 County Health Rankings Maryland Data - v1.xlsx', 4)

# %%
new_maryland_subrank = maryland_subrank[['Unnamed: 0','Unnamed: 1','Unnamed: 2','Quality of Life']]
new_maryland_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
maryland_combined = maryland_data[['Unnamed: 1', 'Unnamed: 2','Unnamed: 155','Adult obesity','Access to exercise opportunities']]
maryland_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
new_maryland = maryland_data2[['Unnamed: 1', 'Unnamed: 2', 'Population', 'Life expectancy','Median household income']]
new_maryland.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Population':'Population', 'Life expectancy':'Life Expectancy', 'Median household income':'Median Household Income'}, inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\779470393.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_maryland_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\779470393.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   maryland_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
# ...

# %%
maryland_half = pd.merge(new_maryland_subrank, new_maryland)
maryland_99 = pd.merge(maryland_half, maryland_combined)
maryland = maryland_99.drop(0)
maryland
# Out:
#     STCOU     State           County Quality of Life Population  \
# 1   24000  Maryland              NaN             NaN    6055802
# 2   24001  Maryland         Allegany        0.360849      70057
# 3   24003  Maryland     Anne Arundel       -0.345333     582777
# 4   24005  Maryland        Baltimore       -0.021833     826017
# 5   24009  Maryland          Calvert       -0.432066      93072
# 6   24011  Maryland         Caroline        0.300572      33492
# 7   24013  Maryland          Carroll       -0.501148     169092
# 8   24015  Maryland            Cecil        0.025422     103419
# 9   24017  Maryland          Charles        0.074416     164436
# 10  24019  Maryland       Dorchester        0.591683      31853
# 11  24021  Maryland        Frederick        -0.40721     265161
# 12  24023  Maryland          Garrett        0.226662      28852
# 13  24025  Maryland          Harford       -0.277429     256805
# 14  24027  Maryland           Howard       -0.586255     328200
# ...

# %%
massachusetts_subrank = pd.read_excel('2022 County Health Rankings Massachusetts Data - v1.xlsx', 2)
massachusetts_data = pd.read_excel('2022 County Health Rankings Massachusetts Data - v1.xlsx', 3)
massachusetts_data2 = pd.read_excel('2022 County Health Rankings Massachusetts Data - v1.xlsx', 4)

# %%
new_massachusetts_subrank = massachusetts_subrank[['Unnamed: 0','Unnamed: 1','Unnamed: 2','Quality of Life']]
new_massachusetts_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
massachusetts_combined = massachusetts_data[['Unnamed: 1', 'Unnamed: 2','Unnamed: 155','Adult obesity','Access to exercise opportunities']]
massachusetts_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
new_massachusetts = massachusetts_data2[['Unnamed: 1', 'Unnamed: 2', 'Population', 'Life expectancy','Median household income']]
new_massachusetts.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Population':'Population', 'Life expectancy':'Life Expectancy', 'Median household income':'Median Household Income'}, inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\961403162.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_massachusetts_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\961403162.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   massachusetts_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
# ...

# %%
massachusetts_half = pd.merge(new_massachusetts_subrank, new_massachusetts)
massachusetts_99 = pd.merge(massachusetts_half, massachusetts_combined)
massachusetts = massachusetts_99.drop(0)
massachusetts
# Out:
#     STCOU          State      County Quality of Life Population  \
# 1   25000  Massachusetts         NaN             NaN    6893574
# 2   25001  Massachusetts  Barnstable       -0.256756     213164
# 3   25003  Massachusetts   Berkshire        0.431841     124571
# 4   25005  Massachusetts     Bristol        0.554282     566765
# 5   25007  Massachusetts       Dukes       -0.490018      17461
# 6   25009  Massachusetts       Essex        0.091085     791263
# 7   25011  Massachusetts    Franklin       -0.096915      70267
# 8   25013  Massachusetts     Hampden        0.769798     463986
# 9   25015  Massachusetts   Hampshire       -0.078611     161401
# 10  25017  Massachusetts   Middlesex       -0.437318    1609379
# 11  25019  Massachusetts   Nantucket       -0.589315      11376
# 12  25021  Massachusetts     Norfolk       -0.448878     709409
# 13  25023  Massachusetts    Plymouth       -0.047808     523738
# 14  25025  Massachusetts     Suffolk        0.454467     801582
# ...

# %%
michigan_subrank = pd.read_excel('2022 County Health Rankings Michigan Data - v1.xlsx', 2)
michigan_data = pd.read_excel('2022 County Health Rankings Michigan Data - v1.xlsx', 3)
michigan_data2 = pd.read_excel('2022 County Health Rankings Michigan Data - v1.xlsx', 4)

# %%
new_michigan_subrank = michigan_subrank[['Unnamed: 0','Unnamed: 1','Unnamed: 2','Quality of Life']]
new_michigan_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
michigan_combined = michigan_data[['Unnamed: 1', 'Unnamed: 2','Unnamed: 155','Adult obesity','Access to exercise opportunities']]
michigan_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
new_michigan = michigan_data2[['Unnamed: 1', 'Unnamed: 2', 'Population', 'Life expectancy','Median household income']]
new_michigan.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Population':'Population', 'Life expectancy':'Life Expectancy', 'Median household income':'Median Household Income'}, inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\3955377740.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_michigan_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\3955377740.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   michigan_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
# ...

# %%
michigan_half = pd.merge(new_michigan_subrank, new_michigan)
michigan_99 = pd.merge(michigan_half, michigan_combined)
michigan = michigan_99.drop(0)
michigan
# Out:
#     STCOU     State     County Quality of Life Population Life Expectancy  \
# 1   26000  Michigan        NaN             NaN    9966555       77.484875
# 2   26001  Michigan     Alcona        0.295515      10505       77.205962
# 3   26003  Michigan      Alger        0.214716       9015       80.066949
# 4   26005  Michigan    Allegan       -0.317683     118927       78.200851
# 5   26007  Michigan     Alpena        0.024623      28238       77.816553
# ..    ...       ...        ...             ...        ...             ...
# 80  26157  Michigan    Tuscola        0.133322      52289       75.963528
# 81  26159  Michigan  Van Buren        -0.02707      75474        77.52838
# 82  26161  Michigan  Washtenaw       -0.703105     366473       80.890781
# 83  26163  Michigan      Wayne        0.832809    1740623       74.342407
# 84  26165  Michigan    Wexford        0.102621      33743       76.939923
#
#    Median Household Income Percent Some College Adult Obesity  \
# ...

# %%
minnesota_subrank = pd.read_excel('2022 County Health Rankings Minnesota Data - v1.xlsx', 2)
minnesota_data = pd.read_excel('2022 County Health Rankings Minnesota Data - v1.xlsx', 3)
minnesota_data2 = pd.read_excel('2022 County Health Rankings Minnesota Data - v1.xlsx', 4)

# %%
new_minnesota_subrank = minnesota_subrank[['Unnamed: 0','Unnamed: 1','Unnamed: 2','Quality of Life']]
new_minnesota_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
minnesota_combined = minnesota_data[['Unnamed: 1', 'Unnamed: 2','Unnamed: 155','Adult obesity','Access to exercise opportunities']]
minnesota_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
new_minnesota = minnesota_data2[['Unnamed: 1', 'Unnamed: 2', 'Population', 'Life expectancy','Median household income']]
new_minnesota.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Population':'Population', 'Life expectancy':'Life Expectancy', 'Median household income':'Median Household Income'}, inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\2645922901.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_minnesota_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\2645922901.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   minnesota_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
# ...

# %%
minnesota_half = pd.merge(new_minnesota_subrank, new_minnesota)
minnesota_99 = pd.merge(minnesota_half, minnesota_combined)
minnesota = minnesota_99.drop(0)
minnesota
# Out:
#     STCOU      State           County Quality of Life Population  \
# 1   27000  Minnesota              NaN             NaN    5657342
# 2   27001  Minnesota           Aitkin       -0.068993      15848
# 3   27003  Minnesota            Anoka       -0.323937     359921
# 4   27005  Minnesota           Becker        0.185798      34456
# 5   27007  Minnesota         Beltrami        0.531918      47442
# ..    ...        ...              ...             ...        ...
# 84  27165  Minnesota         Watonwan        0.175722      10792
# 85  27167  Minnesota           Wilkin        -0.39569       6161
# 86  27169  Minnesota           Winona        0.082005      50485
# 87  27171  Minnesota           Wright       -0.615106     140249
# 88  27173  Minnesota  Yellow Medicine       -0.061104       9580
#
#    Life Expectancy Median Household Income Percent Some College Adult Obesity  \
# 1        80.396039                   75489            75.489831            30
# ...

# %%
mississippi_subrank = pd.read_excel('2022 County Health Rankings Mississippi Data - v1.xlsx', 2)
mississippi_data = pd.read_excel('2022 County Health Rankings Mississippi Data - v1.xlsx', 3)
mississippi_data2 = pd.read_excel('2022 County Health Rankings Mississippi Data - v1.xlsx', 4)

# %%
new_mississippi_subrank = mississippi_subrank[['Unnamed: 0','Unnamed: 1','Unnamed: 2','Quality of Life']]
new_mississippi_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
mississippi_combined = mississippi_data[['Unnamed: 1', 'Unnamed: 2','Unnamed: 155','Adult obesity','Access to exercise opportunities']]
mississippi_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
new_mississippi = mississippi_data2[['Unnamed: 1', 'Unnamed: 2', 'Population', 'Life expectancy','Median household income']]
new_mississippi.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Population':'Population', 'Life expectancy':'Life Expectancy', 'Median household income':'Median Household Income'}, inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\2046338960.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_mississippi_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\2046338960.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mississippi_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
# ...

# %%
mississippi_half = pd.merge(new_mississippi_subrank, new_mississippi)
mississippi_99 = pd.merge(mississippi_half, mississippi_combined)
mississippi = mississippi_99.drop(0)
mississippi
# Out:
#     STCOU        State     County Quality of Life Population Life Expectancy  \
# 1   28000  Mississippi        NaN             NaN    2966786       73.888294
# 2   28001  Mississippi      Adams        0.085928      30275        72.47655
# 3   28003  Mississippi     Alcorn       -0.171783      36889       73.462643
# 4   28005  Mississippi      Amite       -0.038591      12205       75.871747
# 5   28007  Mississippi     Attala        0.245187      18004       73.724446
# ..    ...          ...        ...             ...        ...             ...
# 79  28155  Mississippi    Webster       -0.162953       9676       72.325828
# 80  28157  Mississippi  Wilkinson        0.485855       8351       69.918216
# 81  28159  Mississippi    Winston        0.095962      17845       73.281467
# 82  28161  Mississippi  Yalobusha       -0.143722      11982       70.267927
# 83  28163  Mississippi      Yazoo        0.219598      26982       72.993426
#
# ...

# %%
missouri_subrank = pd.read_excel('2022 County Health Rankings Missouri Data - v1.xlsx', 2)
missouri_data = pd.read_excel('2022 County Health Rankings Missouri Data - v1.xlsx', 3)
missouri_data2 = pd.read_excel('2022 County Health Rankings Missouri Data - v1.xlsx', 4)

# %%
new_missouri_subrank = missouri_subrank[['Unnamed: 0','Unnamed: 1','Unnamed: 2','Quality of Life']]
new_missouri_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
missouri_combined = missouri_data[['Unnamed: 1', 'Unnamed: 2','Unnamed: 155','Adult obesity','Access to exercise opportunities']]
missouri_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
new_missouri = missouri_data2[['Unnamed: 1', 'Unnamed: 2', 'Population', 'Life expectancy','Median household income']]
new_missouri.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Population':'Population', 'Life expectancy':'Life Expectancy', 'Median household income':'Median Household Income'}, inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\2474797544.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_missouri_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\2474797544.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   missouri_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
# ...

# %%
missouri_half = pd.merge(new_missouri_subrank, new_missouri)
missouri_99 = pd.merge(missouri_half, missouri_combined)
missouri = missouri_99.drop(0)
missouri
# Out:
#      STCOU     State          County Quality of Life Population  \
# 1    29000  Missouri             NaN             NaN    6151548
# 2    29001  Missouri           Adair       -0.012289      25399
# 3    29003  Missouri          Andrew       -0.532668      17586
# 4    29005  Missouri        Atchison       -0.882525       5096
# 5    29007  Missouri         Audrain         0.24891      24835
# ..     ...       ...             ...             ...        ...
# 112  29223  Missouri           Wayne          0.6741      12769
# 113  29225  Missouri         Webster       -0.114092      39859
# 114  29227  Missouri           Worth         0.00778       1953
# 115  29229  Missouri          Wright        0.444002      18325
# 116  29510  Missouri  St. Louis City        0.520679     297645
#
#     Life Expectancy Median Household Income Percent Some College  \
# 1         76.635512                   58812             67.29913
# ...

# %%
montana_subrank = pd.read_excel('2022 County Health Rankings Montana Data - v1.xlsx', 2)
montana_data = pd.read_excel('2022 County Health Rankings Montana Data - v1.xlsx', 3)
montana_data2 = pd.read_excel('2022 County Health Rankings Montana Data - v1.xlsx', 4)

# %%
new_montana_subrank = montana_subrank[['Unnamed: 0','Unnamed: 1','Unnamed: 2','Quality of Life']]
new_montana_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
montana_combined = montana_data[['Unnamed: 1', 'Unnamed: 2','Unnamed: 155','Adult obesity','Access to exercise opportunities']]
montana_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
new_montana = montana_data2[['Unnamed: 1', 'Unnamed: 2', 'Population', 'Life expectancy','Median household income']]
new_montana.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Population':'Population', 'Life expectancy':'Life Expectancy', 'Median household income':'Median Household Income'}, inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\18191674.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_montana_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\18191674.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   montana_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
# ...

# %%
montana_half = pd.merge(new_montana_subrank, new_montana)
montana_99 = pd.merge(montana_half, montana_combined)
montana = montana_99.drop(0)
montana
# Out:
#     STCOU    State           County Quality of Life Population  \
# 1   30000  Montana              NaN             NaN    1080577
# 2   30001  Montana       Beaverhead       -0.296342       9483
# 3   30003  Montana         Big Horn         0.93116      13063
# 4   30005  Montana           Blaine        0.787325       6568
# 5   30007  Montana       Broadwater       -0.527785       6444
# 6   30009  Montana           Carbon       -0.633278      10921
# 7   30011  Montana           Carter             NaN       1235
# 8   30013  Montana          Cascade         0.02588      81346
# 9   30015  Montana         Chouteau        0.229546       5699
# 10  30017  Montana           Custer       -0.253727      11292
# 11  30019  Montana          Daniels             NaN       1638
# 12  30021  Montana           Dawson       -0.257263       8555
# 13  30023  Montana       Deer Lodge        0.439629       9204
# 14  30025  Montana           Fallon        -0.27637       2826
# ...

# %%
nebraska_subrank = pd.read_excel('2022 County Health Rankings Nebraska Data - v1.xlsx', 2)
nebraska_data = pd.read_excel('2022 County Health Rankings Nebraska Data - v1.xlsx', 3)
nebraska_data2 = pd.read_excel('2022 County Health Rankings Nebraska Data - v1.xlsx', 4)

# %%
new_nebraska_subrank = nebraska_subrank[['Unnamed: 0','Unnamed: 1','Unnamed: 2','Quality of Life']]
new_nebraska_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
nebraska_combined = nebraska_data[['Unnamed: 1', 'Unnamed: 2','Unnamed: 155','Adult obesity','Access to exercise opportunities']]
nebraska_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
new_nebraska = nebraska_data2[['Unnamed: 1', 'Unnamed: 2', 'Population', 'Life expectancy','Median household income']]
new_nebraska.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Population':'Population', 'Life expectancy':'Life Expectancy', 'Median household income':'Median Household Income'}, inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\3184877164.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_nebraska_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\3184877164.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nebraska_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
# ...

# %%
nebraska_half = pd.merge(new_nebraska_subrank, new_nebraska)
nebraska_99 = pd.merge(nebraska_half, nebraska_combined)
nebraska = nebraska_99.drop(0)
nebraska
# Out:
#     STCOU     State      County Quality of Life Population Life Expectancy  \
# 1   31000  Nebraska         NaN             NaN    1937552       79.015864
# 2   31001  Nebraska       Adams       -0.003258      31321       77.863713
# 3   31003  Nebraska    Antelope       -0.209523       6264       82.662863
# 4   31005  Nebraska      Arthur             NaN        466             NaN
# 5   31007  Nebraska      Banner             NaN        786             NaN
# ..    ...       ...         ...             ...        ...             ...
# 90  31177  Nebraska  Washington       -0.384298      20901       80.956918
# 91  31179  Nebraska       Wayne       -0.341043       9492       83.217758
# 92  31181  Nebraska     Webster        0.164553       3419       76.965504
# 93  31183  Nebraska     Wheeler             NaN        790             NaN
# 94  31185  Nebraska        York        -0.37365      13511       79.726758
#
#    Median Household Income Percent Some College Adult Obesity  \
# ...

# %%
nevada_subrank = pd.read_excel('2022 County Health Rankings Nevada Data - v1.xlsx', 2)
nevada_data = pd.read_excel('2022 County Health Rankings Nevada Data - v1.xlsx', 3)
nevada_data2 = pd.read_excel('2022 County Health Rankings Nevada Data - v1.xlsx', 4)

# %%
new_nevada_subrank = nevada_subrank[['Unnamed: 0','Unnamed: 1','Unnamed: 2','Quality of Life']]
new_nevada_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
nevada_combined = nevada_data[['Unnamed: 1', 'Unnamed: 2','Unnamed: 155','Adult obesity','Access to exercise opportunities']]
nevada_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
new_nevada = nevada_data2[['Unnamed: 1', 'Unnamed: 2', 'Population', 'Life expectancy','Median household income']]
new_nevada.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Population':'Population', 'Life expectancy':'Life Expectancy', 'Median household income':'Median Household Income'}, inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\3051495814.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_nevada_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\3051495814.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nevada_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
# ...

# %%
nevada_half = pd.merge(new_nevada_subrank, new_nevada)
nevada_99 = pd.merge(nevada_half, nevada_combined)
nevada = nevada_99.drop(0)
nevada
# Out:
#     STCOU   State       County Quality of Life Population Life Expectancy  \
# 1   32000  Nevada          NaN             NaN    3138259       78.109184
# 2   32001  Nevada    Churchill       -0.180166      25363       74.179542
# 3   32003  Nevada        Clark       -0.032114    2315963       78.409531
# 4   32005  Nevada      Douglas       -0.381857      49088       81.110153
# 5   32007  Nevada         Elko       -0.163714      53006       78.483466
# 6   32009  Nevada    Esmeralda             NaN        886             NaN
# 7   32011  Nevada       Eureka       -0.040774       2065       79.000961
# 8   32013  Nevada     Humboldt       -0.011135      16962       76.984826
# 9   32015  Nevada       Lander        0.759057       5514       75.552398
# 10  32017  Nevada      Lincoln       -0.287746       5159       81.765779
# 11  32019  Nevada         Lyon        0.229582      58319       76.200114
# 12  32021  Nevada      Mineral        0.595026       4518       71.614511
# ...

# %%
newhampshire_subrank = pd.read_excel('2022 County Health Rankings New Hampshire Data - v1.xlsx', 2)
newhampshire_data = pd.read_excel('2022 County Health Rankings New Hampshire Data - v1.xlsx', 3)
newhampshire_data2 = pd.read_excel('2022 County Health Rankings New Hampshire Data - v1.xlsx', 4)

# %%
new_newhampshire_subrank = newhampshire_subrank[['Unnamed: 0','Unnamed: 1','Unnamed: 2','Quality of Life']]
new_newhampshire_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
newhampshire_combined = newhampshire_data[['Unnamed: 1', 'Unnamed: 2','Unnamed: 155','Adult obesity','Access to exercise opportunities']]
newhampshire_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
new_newhampshire = newhampshire_data2[['Unnamed: 1', 'Unnamed: 2', 'Population', 'Life expectancy','Median household income']]
new_newhampshire.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Population':'Population', 'Life expectancy':'Life Expectancy', 'Median household income':'Median Household Income'}, inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\3587282912.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_newhampshire_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\3587282912.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newhampshire_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
# ...

# %%
newhampshire_half = pd.merge(new_newhampshire_subrank, new_newhampshire)
newhampshire_99 = pd.merge(newhampshire_half, newhampshire_combined)
newhampshire = newhampshire_99.drop(0)
newhampshire
# Out:
#     STCOU          State        County Quality of Life Population  \
# 1   33000  New Hampshire           NaN             NaN    1366275
# 2   33001  New Hampshire       Belknap        0.235979      61551
# 3   33003  New Hampshire       Carroll       -0.260646      49167
# 4   33005  New Hampshire      Cheshire       -0.324123      76228
# 5   33007  New Hampshire          Coos        0.884315      31174
# 6   33009  New Hampshire       Grafton        0.001879      90691
# 7   33011  New Hampshire  Hillsborough       -0.097448     418735
# 8   33013  New Hampshire     Merrimack       -0.260541     152622
# 9   33015  New Hampshire    Rockingham       -0.598918     311307
# 10  33017  New Hampshire     Strafford        0.022014     131533
# 11  33019  New Hampshire      Sullivan        0.397491      43267
#
#    Life Expectancy Median Household Income Percent Some College Adult Obesity  \
# 1        79.589043                   81415            70.903558          32.1
# ...

# %%
newjersey_subrank = pd.read_excel('2022 County Health Rankings New Jersey Data - v1.xlsx', 2)
newjersey_data = pd.read_excel('2022 County Health Rankings New Jersey Data - v1.xlsx', 3)
newjersey_data2 = pd.read_excel('2022 County Health Rankings New Jersey Data - v1.xlsx', 4)

# %%
new_newjersey_subrank = newjersey_subrank[['Unnamed: 0','Unnamed: 1','Unnamed: 2','Quality of Life']]
new_newjersey_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
newjersey_combined = newjersey_data[['Unnamed: 1', 'Unnamed: 2','Unnamed: 155','Adult obesity','Access to exercise opportunities']]
newjersey_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
new_newjersey = newjersey_data2[['Unnamed: 1', 'Unnamed: 2', 'Population', 'Life expectancy','Median household income']]
new_newjersey.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Population':'Population', 'Life expectancy':'Life Expectancy', 'Median household income':'Median Household Income'}, inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\3754790464.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_newjersey_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\3754790464.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newjersey_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
# ...

# %%
newjersey_half = pd.merge(new_newjersey_subrank, new_newjersey)
newjersey_99 = pd.merge(newjersey_half, newjersey_combined)
newjersey = newjersey_99.drop(0)
newjersey
# Out:
#     STCOU       State      County Quality of Life Population Life Expectancy  \
# 1   34000  New Jersey         NaN             NaN    8882371       79.488449
# 2   34001  New Jersey    Atlantic        0.253805     262945       76.680523
# 3   34003  New Jersey      Bergen       -0.360073     930394       82.142488
# 4   34005  New Jersey  Burlington        0.022551     446596       79.124622
# 5   34007  New Jersey      Camden        0.372229     506809       76.692071
# 6   34009  New Jersey    Cape May       -0.081993      91546       76.872813
# 7   34011  New Jersey  Cumberland        1.000078     147008       74.602311
# 8   34013  New Jersey       Essex        0.519773     800501       78.022446
# 9   34015  New Jersey  Gloucester        0.081585     293245        77.22681
# 10  34017  New Jersey      Hudson        0.197371     671666       80.480667
# 11  34019  New Jersey   Hunterdon       -0.621681     124797       83.169787
# ...

# %%
newmexico_subrank = pd.read_excel('2022 County Health Rankings New Mexico Data - v1.xlsx', 2)
newmexico_data = pd.read_excel('2022 County Health Rankings New Mexico Data - v1.xlsx', 3)
newmexico_data2 = pd.read_excel('2022 County Health Rankings New Mexico Data - v1.xlsx', 4)

# %%
new_newmexico_subrank = newmexico_subrank[['Unnamed: 0','Unnamed: 1','Unnamed: 2','Quality of Life']]
new_newmexico_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
newmexico_combined = newmexico_data[['Unnamed: 1', 'Unnamed: 2','Unnamed: 155','Adult obesity','Access to exercise opportunities']]
newmexico_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
new_newmexico = newmexico_data2[['Unnamed: 1', 'Unnamed: 2', 'Population', 'Life expectancy','Median household income']]
new_newmexico.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Population':'Population', 'Life expectancy':'Life Expectancy', 'Median household income':'Median Household Income'}, inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\3998082122.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_newmexico_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\3998082122.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newmexico_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
# ...

# %%
newmexico_half = pd.merge(new_newmexico_subrank, new_newmexico)
newmexico_99 = pd.merge(newmexico_half, newmexico_combined)
newmexico = newmexico_99.drop(0)
newmexico
# Out:
#     STCOU       State      County Quality of Life Population Life Expectancy  \
# 1   35000  New Mexico         NaN             NaN    2106319       76.881751
# 2   35001  New Mexico  Bernalillo       -0.266189     681666       77.395743
# 3   35003  New Mexico      Catron        0.030744       3623       80.352121
# 4   35005  New Mexico      Chaves       -0.002055      64711       74.535654
# 5   35006  New Mexico      Cibola        0.430258      26354       74.411339
# 6   35007  New Mexico      Colfax        0.501847      11927       76.944853
# 7   35009  New Mexico       Curry       -0.044353      48793       76.065209
# 8   35011  New Mexico     De Baca        0.078503       1673       77.250439
# 9   35013  New Mexico    Dona Ana       -0.092463     221262       78.624438
# 10  35015  New Mexico        Eddy       -0.247197      58418       74.338706
# 11  35017  New Mexico       Grant       -0.026526      27007       76.784768
# ...

# %%
newyork_subrank = pd.read_excel('2022 County Health Rankings New York Data - v1.xlsx', 2)
newyork_data = pd.read_excel('2022 County Health Rankings New York Data - v1.xlsx', 3)
newyork_data2 = pd.read_excel('2022 County Health Rankings New York Data - v1.xlsx', 4)

# %%
new_newyork_subrank = newyork_subrank[['Unnamed: 0','Unnamed: 1','Unnamed: 2','Quality of Life']]
new_newyork_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
newyork_combined = newyork_data[['Unnamed: 1', 'Unnamed: 2','Unnamed: 155','Adult obesity','Access to exercise opportunities']]
newyork_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
new_newyork = newyork_data2[['Unnamed: 1', 'Unnamed: 2', 'Population', 'Life expectancy','Median household income']]
new_newyork.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Population':'Population', 'Life expectancy':'Life Expectancy', 'Median household income':'Median Household Income'}, inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\2012402608.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_newyork_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\2012402608.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newyork_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
# ...

# %%
newyork_half = pd.merge(new_newyork_subrank, new_newyork)
newyork_99 = pd.merge(newyork_half, newyork_combined)
newyork = newyork_99.drop(0)
newyork
# Out:
#     STCOU     State       County Quality of Life Population Life Expectancy  \
# 1   36000  New York          NaN             NaN   19336776         80.2606
# 2   36001  New York       Albany       -0.136827     303654       79.423543
# 3   36003  New York     Allegany        0.131427      45587       77.886721
# 4   36005  New York        Bronx        1.298329    1401142       77.995462
# 5   36007  New York       Broome        0.209314     189420       78.079695
# ..    ...       ...          ...             ...        ...             ...
# 59  36115  New York   Washington        0.149529      60606       78.283916
# 60  36117  New York        Wayne        0.031202      89339        78.65462
# 61  36119  New York  Westchester       -0.338233     965802       82.405727
# 62  36121  New York      Wyoming       -0.056481      39465       78.880361
# 63  36123  New York        Yates       -0.497995      24780       77.723896
#
# ...

# %%
northcarolina_subrank = pd.read_excel('2022 County Health Rankings North Carolina Data - v1.xlsx', 2)
northcarolina_data = pd.read_excel('2022 County Health Rankings North Carolina Data - v1.xlsx', 3)
northcarolina_data2 = pd.read_excel('2022 County Health Rankings North Carolina Data - v1.xlsx', 4)

# %%
new_northcarolina_subrank = northcarolina_subrank[['Unnamed: 0','Unnamed: 1','Unnamed: 2','Quality of Life']]
new_northcarolina_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
northcarolina_combined = northcarolina_data[['Unnamed: 1', 'Unnamed: 2','Unnamed: 155','Adult obesity','Access to exercise opportunities']]
northcarolina_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
new_northcarolina = northcarolina_data2[['Unnamed: 1', 'Unnamed: 2', 'Population', 'Life expectancy','Median household income']]
new_northcarolina.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Population':'Population', 'Life expectancy':'Life Expectancy', 'Median household income':'Median Household Income'}, inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\2004901127.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_northcarolina_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\2004901127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   northcarolina_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
# ...

# %%
northcarolina_half = pd.merge(new_northcarolina_subrank, new_northcarolina)
northcarolina_99 = pd.merge(northcarolina_half, northcarolina_combined)
northcarolina = northcarolina_99.drop(0)
northcarolina
# Out:
#      STCOU           State     County Quality of Life Population  \
# 1    37000  North Carolina        NaN             NaN   10600823
# 2    37001  North Carolina   Alamance       -0.080483     171346
# 3    37003  North Carolina  Alexander       -0.108315      37441
# 4    37005  North Carolina  Alleghany        0.174189      11194
# 5    37007  North Carolina      Anson        0.723335      24097
# ..     ...             ...        ...             ...        ...
# 97   37191  North Carolina      Wayne        0.087287     123967
# 98   37193  North Carolina     Wilkes         0.23083      68043
# 99   37195  North Carolina     Wilson        0.455813      81979
# 100  37197  North Carolina     Yadkin        0.107082      37625
# 101  37199  North Carolina     Yancey       -0.067434      18099
#
#     Life Expectancy Median Household Income Percent Some College  \
# 1         77.677785                   59616            68.227131
# ...

# %%
northdakota_subrank = pd.read_excel('2022 County Health Rankings North Dakota Data - v1.xlsx', 2)
northdakota_data = pd.read_excel('2022 County Health Rankings North Dakota Data - v1.xlsx', 3)
northdakota_data2 = pd.read_excel('2022 County Health Rankings North Dakota Data - v1.xlsx', 4)

# %%
new_northdakota_subrank = northdakota_subrank[['Unnamed: 0','Unnamed: 1','Unnamed: 2','Quality of Life']]
new_northdakota_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
northdakota_combined = northdakota_data[['Unnamed: 1', 'Unnamed: 2','Unnamed: 155','Adult obesity','Access to exercise opportunities']]
northdakota_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
new_northdakota = northdakota_data2[['Unnamed: 1', 'Unnamed: 2', 'Population', 'Life expectancy','Median household income']]
new_northdakota.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Population':'Population', 'Life expectancy':'Life Expectancy', 'Median household income':'Median Household Income'}, inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\3306719259.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_northdakota_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\3306719259.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   northdakota_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
# ...

# %%
northdakota_half = pd.merge(new_northdakota_subrank, new_northdakota)
northdakota_99 = pd.merge(northdakota_half, northdakota_combined)
northdakota = northdakota_99.drop(0)
northdakota
# Out:
#     STCOU         State         County Quality of Life Population  \
# 1   38000  North Dakota            NaN             NaN     765309
# 2   38001  North Dakota          Adams       -0.136597       2188
# 3   38003  North Dakota         Barnes       -0.212316      10402
# 4   38005  North Dakota         Benson        1.003887       6762
# 5   38007  North Dakota       Billings             NaN        890
# 6   38009  North Dakota      Bottineau       -0.290052       6287
# 7   38011  North Dakota         Bowman       -0.105999       2986
# 8   38013  North Dakota          Burke       -0.142098       2118
# 9   38015  North Dakota       Burleigh       -0.278369      96212
# 10  38017  North Dakota           Cass       -0.235827     183904
# 11  38019  North Dakota       Cavalier        0.431132       3713
# 12  38021  North Dakota         Dickey       -0.474588       4705
# 13  38023  North Dakota         Divide       -0.110456       2277
# ...

# %%
ohio_subrank = pd.read_excel('2022 County Health Rankings Ohio Data - v1.xlsx', 2)
ohio_data = pd.read_excel('2022 County Health Rankings Ohio Data - v1.xlsx', 3)
ohio_data2 = pd.read_excel('2022 County Health Rankings Ohio Data - v1.xlsx', 4)

# %%
new_ohio_subrank = ohio_subrank[['Unnamed: 0','Unnamed: 1','Unnamed: 2','Quality of Life']]
new_ohio_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
ohio_combined = ohio_data[['Unnamed: 1', 'Unnamed: 2','Unnamed: 155','Adult obesity','Access to exercise opportunities']]
ohio_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
new_ohio = ohio_data2[['Unnamed: 1', 'Unnamed: 2', 'Population', 'Life expectancy','Median household income']]
new_ohio.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Population':'Population', 'Life expectancy':'Life Expectancy', 'Median household income':'Median Household Income'}, inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\3821953881.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_ohio_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\3821953881.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ohio_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
# ...

# %%
ohio_half = pd.merge(new_ohio_subrank, new_ohio)
ohio_99 = pd.merge(ohio_half, ohio_combined)
ohio = ohio_99.drop(0)
ohio
# Out:
#     STCOU State      County Quality of Life Population Life Expectancy  \
# 1   39000  Ohio         NaN             NaN   11693217       76.523935
# 2   39001  Ohio       Adams        0.892017      27531       73.524077
# 3   39003  Ohio       Allen        0.323063     101980       76.254724
# 4   39005  Ohio     Ashland       -0.283653      53362       77.286224
# 5   39007  Ohio   Ashtabula        0.462957      96513        75.22431
# ..    ...   ...         ...             ...        ...             ...
# 85  39167  Ohio  Washington       -0.082501      59652       76.703839
# 86  39169  Ohio       Wayne       -0.293689     115694       77.520723
# 87  39171  Ohio    Williams       -0.424923      36565       77.126836
# 88  39173  Ohio        Wood       -0.459511     131113       78.252789
# 89  39175  Ohio     Wyandot       -0.096743      21711       76.665792
#
#    Median Household Income Percent Some College Adult Obesity  \
# ...

# %%
oklahoma_subrank = pd.read_excel('2022 County Health Rankings Oklahoma Data - v1.xlsx', 2)
oklahoma_data = pd.read_excel('2022 County Health Rankings Oklahoma Data - v1.xlsx', 3)
oklahoma_data2 = pd.read_excel('2022 County Health Rankings Oklahoma Data - v1.xlsx', 4)

# %%
new_oklahoma_subrank = oklahoma_subrank[['Unnamed: 0','Unnamed: 1','Unnamed: 2','Quality of Life']]
new_oklahoma_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
oklahoma_combined = oklahoma_data[['Unnamed: 1', 'Unnamed: 2','Unnamed: 155','Adult obesity','Access to exercise opportunities']]
oklahoma_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
new_oklahoma = oklahoma_data2[['Unnamed: 1', 'Unnamed: 2', 'Population', 'Life expectancy','Median household income']]
new_oklahoma.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Population':'Population', 'Life expectancy':'Life Expectancy', 'Median household income':'Median Household Income'}, inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\1936907431.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_oklahoma_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\1936907431.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   oklahoma_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
# ...

# %%
oklahoma_half = pd.merge(new_oklahoma_subrank, new_oklahoma)
oklahoma_99 = pd.merge(oklahoma_half, oklahoma_combined)
oklahoma = oklahoma_99.drop(0)
oklahoma
# Out:
#     STCOU     State      County Quality of Life Population Life Expectancy  \
# 1   40000  Oklahoma         NaN             NaN    3980783       75.536413
# 2   40001  Oklahoma       Adair        0.771279      21955         73.3526
# 3   40003  Oklahoma     Alfalfa       -0.836289       5718       77.012707
# 4   40005  Oklahoma       Atoka        0.506822      13912        75.28843
# 5   40007  Oklahoma      Beaver       -0.565913       5207       77.397245
# ..    ...       ...         ...             ...        ...             ...
# 74  40145  Oklahoma     Wagoner       -0.348091      82925       78.755871
# 75  40147  Oklahoma  Washington       -0.353969      52222       75.979413
# 76  40149  Oklahoma     Washita       -0.334426      10830       73.864816
# 77  40151  Oklahoma       Woods        -0.56688       8687       75.416777
# 78  40153  Oklahoma    Woodward       -0.134182      19812       76.071002
#
#    Median Household Income Percent Some College Adult Obesity  \
# ...

# %%
oregon_subrank = pd.read_excel('2022 County Health Rankings Oregon Data - v1.xlsx', 2)
oregon_data = pd.read_excel('2022 County Health Rankings Oregon Data - v1.xlsx', 3)
oregon_data2 = pd.read_excel('2022 County Health Rankings Oregon Data - v1.xlsx', 4)

# %%
new_oregon_subrank = oregon_subrank[['Unnamed: 0','Unnamed: 1','Unnamed: 2','Quality of Life']]
new_oregon_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
oregon_combined = oregon_data[['Unnamed: 1', 'Unnamed: 2','Unnamed: 155','Adult obesity','Access to exercise opportunities']]
oregon_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
new_oregon = oregon_data2[['Unnamed: 1', 'Unnamed: 2', 'Population', 'Life expectancy','Median household income']]
new_oregon.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Population':'Population', 'Life expectancy':'Life Expectancy', 'Median household income':'Median Household Income'}, inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\3210799540.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_oregon_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\3210799540.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   oregon_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
# ...

# %%
oregon_half = pd.merge(new_oregon_subrank, new_oregon)
oregon_99 = pd.merge(oregon_half, oregon_combined)
oregon = oregon_99.drop(0)
oregon
# Out:
#     STCOU   State      County Quality of Life Population Life Expectancy  \
# 1   41000  Oregon         NaN             NaN    4241507       79.701586
# 2   41001  Oregon       Baker        0.247222      16284       76.598802
# 3   41003  Oregon      Benton       -0.711415      93239       83.088542
# 4   41005  Oregon   Clackamas       -0.710691     421596       80.872278
# 5   41007  Oregon     Clatsop        -0.14265      40423       79.570382
# 6   41009  Oregon    Columbia       -0.112019      52876       79.462158
# 7   41011  Oregon        Coos        0.216168      64711       77.456497
# 8   41013  Oregon       Crook        0.189474      25105       79.259491
# 9   41015  Oregon       Curry       -0.124659      23305        76.96983
# 10  41017  Oregon   Deschutes       -0.391117     201769       81.688506
# 11  41019  Oregon     Douglas        0.261255     111364        76.77817
# 12  41021  Oregon     Gilliam        0.693973       1975       84.810572
# ...

# %%
pennsylvania_subrank = pd.read_excel('2022 County Health Rankings Pennsylvania Data - v1.xlsx', 2)
pennsylvania_data = pd.read_excel('2022 County Health Rankings Pennsylvania Data - v1.xlsx', 3)
pennsylvania_data2 = pd.read_excel('2022 County Health Rankings Pennsylvania Data - v1.xlsx', 4)

# %%
new_pennsylvania_subrank = pennsylvania_subrank[['Unnamed: 0','Unnamed: 1','Unnamed: 2','Quality of Life']]
new_pennsylvania_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
pennsylvania_combined = pennsylvania_data[['Unnamed: 1', 'Unnamed: 2','Unnamed: 155','Adult obesity','Access to exercise opportunities']]
pennsylvania_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
new_pennsylvania = pennsylvania_data2[['Unnamed: 1', 'Unnamed: 2', 'Population', 'Life expectancy','Median household income']]
new_pennsylvania.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Population':'Population', 'Life expectancy':'Life Expectancy', 'Median household income':'Median Household Income'}, inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\1321949202.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_pennsylvania_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\1321949202.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pennsylvania_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
# ...

# %%
pennsylvania_half = pd.merge(new_pennsylvania_subrank, new_pennsylvania)
pennsylvania_99 = pd.merge(pennsylvania_half, pennsylvania_combined)
pennsylvania = pennsylvania_99.drop(0)
pennsylvania
# Out:
#     STCOU         State        County Quality of Life Population  \
# 1   42000  Pennsylvania           NaN             NaN   12783254
# 2   42001  Pennsylvania         Adams       -0.201002     102742
# 3   42003  Pennsylvania     Allegheny       -0.290436    1211358
# 4   42005  Pennsylvania     Armstrong        0.091243      64162
# 5   42007  Pennsylvania        Beaver       -0.183337     162575
# ..    ...           ...           ...             ...        ...
# 64  42125  Pennsylvania    Washington       -0.300194     206803
# 65  42127  Pennsylvania         Wayne       -0.013726      51163
# 66  42129  Pennsylvania  Westmoreland       -0.337555     347087
# 67  42131  Pennsylvania       Wyoming       -0.213452      26557
# 68  42133  Pennsylvania          York       -0.034627     450448
#
#    Life Expectancy Median Household Income Percent Some College Adult Obesity  \
# 1        78.016447                   64898            66.681453          33.1
# ...

# %%
rhodeisland_subrank = pd.read_excel('2022 County Health Rankings Rhode Island Data - v1.xlsx', 2)
rhodeisland_data = pd.read_excel('2022 County Health Rankings Rhode Island Data - v1.xlsx', 3)
rhodeisland_data2 = pd.read_excel('2022 County Health Rankings Rhode Island Data - v1.xlsx', 4)

# %%
new_rhodeisland_subrank = rhodeisland_subrank[['Unnamed: 0','Unnamed: 1','Unnamed: 2','Quality of Life']]
new_rhodeisland_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
rhodeisland_combined = rhodeisland_data[['Unnamed: 1', 'Unnamed: 2','Unnamed: 155','Adult obesity','Access to exercise opportunities']]
rhodeisland_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
new_rhodeisland = rhodeisland_data2[['Unnamed: 1', 'Unnamed: 2', 'Population', 'Life expectancy','Median household income']]
new_rhodeisland.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Population':'Population', 'Life expectancy':'Life Expectancy', 'Median household income':'Median Household Income'}, inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\173125715.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_rhodeisland_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\173125715.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rhodeisland_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
# ...

# %%
rhodeisland_half = pd.merge(new_rhodeisland_subrank, new_rhodeisland)
rhodeisland_99 = pd.merge(rhodeisland_half, rhodeisland_combined)
rhodeisland = rhodeisland_99.drop(0)
rhodeisland
# Out:
#    STCOU         State      County Quality of Life Population Life Expectancy  \
# 1  44000  Rhode Island         NaN             NaN    1057125       79.371068
# 2  44001  Rhode Island     Bristol       -0.343176      48350       81.154968
# 3  44003  Rhode Island        Kent        0.025501     164646       78.963427
# 4  44005  Rhode Island     Newport       -0.274409      81836       82.019912
# 5  44007  Rhode Island  Providence        0.794388     636547       78.674091
# 6  44009  Rhode Island  Washington       -0.202304     125746       80.782324
#
#   Median Household Income Percent Some College Adult Obesity  Percent Exercise
# 1                   73919            67.975447          30.1         87.503028
# 2                   94591            82.305914          26.8         88.208521
# 3                   82413            69.627146          29.6         78.097955
# 4                   81218            78.426102          28.2         75.330567
# ...

# %%
southcarolina_subrank = pd.read_excel('2022 County Health Rankings South Carolina Data - v1.xlsx', 2)
southcarolina_data = pd.read_excel('2022 County Health Rankings South Carolina Data - v1.xlsx', 3)
southcarolina_data2 = pd.read_excel('2022 County Health Rankings South Carolina Data - v1.xlsx', 4)

# %%
new_southcarolina_subrank = southcarolina_subrank[['Unnamed: 0','Unnamed: 1','Unnamed: 2','Quality of Life']]
new_southcarolina_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
southcarolina_combined = southcarolina_data[['Unnamed: 1', 'Unnamed: 2','Unnamed: 155','Adult obesity','Access to exercise opportunities']]
southcarolina_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
new_southcarolina = southcarolina_data2[['Unnamed: 1', 'Unnamed: 2', 'Population', 'Life expectancy','Median household income']]
new_southcarolina.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Population':'Population', 'Life expectancy':'Life Expectancy', 'Median household income':'Median Household Income'}, inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\1137020497.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_southcarolina_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\1137020497.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   southcarolina_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
# ...

# %%
southcarolina_half = pd.merge(new_southcarolina_subrank, new_southcarolina)
southcarolina_99 = pd.merge(southcarolina_half, southcarolina_combined)
southcarolina = southcarolina_99.drop(0)
southcarolina
# Out:
#     STCOU           State        County Quality of Life Population  \
# 1   45000  South Carolina           NaN             NaN    5218040
# 2   45001  South Carolina     Abbeville       -0.015061      24404
# 3   45003  South Carolina         Aiken       -0.335371     172895
# 4   45005  South Carolina     Allendale        0.820685       8331
# 5   45007  South Carolina      Anderson       -0.287628     204353
# 6   45009  South Carolina       Bamberg        0.290042      13906
# 7   45011  South Carolina      Barnwell        0.401313      20805
# 8   45013  South Carolina      Beaufort       -0.912631     195656
# 9   45015  South Carolina      Berkeley       -0.526554     235987
# 10  45017  South Carolina       Calhoun       -0.101177      14554
# 11  45019  South Carolina    Charleston        -0.70847     417981
# 12  45021  South Carolina      Cherokee        0.306957      57316
# 13  45023  South Carolina       Chester        0.203764      32232
# ...

# %%
southdakota_subrank = pd.read_excel('2022 County Health Rankings South Dakota Data - v1.xlsx', 2)
southdakota_data = pd.read_excel('2022 County Health Rankings South Dakota Data - v1.xlsx', 3)
southdakota_data2 = pd.read_excel('2022 County Health Rankings South Dakota Data - v1.xlsx', 4)

# %%
new_southdakota_subrank = southdakota_subrank[['Unnamed: 0','Unnamed: 1','Unnamed: 2','Quality of Life']]
new_southdakota_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
southdakota_combined = southdakota_data[['Unnamed: 1', 'Unnamed: 2','Unnamed: 155','Adult obesity','Access to exercise opportunities']]
southdakota_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
new_southdakota = southdakota_data2[['Unnamed: 1', 'Unnamed: 2', 'Population', 'Life expectancy','Median household income']]
new_southdakota.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Population':'Population', 'Life expectancy':'Life Expectancy', 'Median household income':'Median Household Income'}, inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\3527605505.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_southdakota_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\3527605505.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   southdakota_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
# ...

# %%
southdakota_half = pd.merge(new_southdakota_subrank, new_southdakota)
southdakota_99 = pd.merge(southdakota_half, southdakota_combined)
southdakota = southdakota_99.drop(0)
southdakota
# Out:
#     STCOU         State     County Quality of Life Population Life Expectancy  \
# 1   46000  South Dakota        NaN             NaN     892717       78.194909
# 2   46003  South Dakota     Aurora       -0.155105       2730       78.316554
# 3   46005  South Dakota     Beadle        0.070428      18513       77.954087
# 4   46007  South Dakota    Bennett        0.371518       3399       71.081746
# 5   46009  South Dakota  Bon Homme       -0.282614       6848       80.047593
# ..    ...           ...        ...             ...        ...             ...
# 63  46125  South Dakota     Turner       -0.319137       8368       78.035418
# 64  46127  South Dakota      Union       -0.221924      16192       79.960197
# 65  46129  South Dakota   Walworth       -0.176479       5336       79.144475
# 66  46135  South Dakota    Yankton       -0.047302      22742       79.098605
# 67  46137  South Dakota    Ziebach        1.095433       2656       76.884793
#
# ...

# %%
tennessee_subrank = pd.read_excel('2022 County Health Rankings Tennessee Data - v1.xlsx', 2)
tennessee_data = pd.read_excel('2022 County Health Rankings Tennessee Data - v1.xlsx', 3)
tennessee_data2 = pd.read_excel('2022 County Health Rankings Tennessee Data - v1.xlsx', 4)

# %%
new_tennessee_subrank = tennessee_subrank[['Unnamed: 0','Unnamed: 1','Unnamed: 2','Quality of Life']]
new_tennessee_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
tennessee_combined = tennessee_data[['Unnamed: 1', 'Unnamed: 2','Unnamed: 155','Adult obesity','Access to exercise opportunities']]
tennessee_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
new_tennessee = tennessee_data2[['Unnamed: 1', 'Unnamed: 2', 'Population', 'Life expectancy','Median household income']]
new_tennessee.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Population':'Population', 'Life expectancy':'Life Expectancy', 'Median household income':'Median Household Income'}, inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\911814634.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_tennessee_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\911814634.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tennessee_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
# ...

# %%
tennessee_half = pd.merge(new_tennessee_subrank, new_tennessee)
tennessee_99 = pd.merge(tennessee_half, tennessee_combined)
tennessee = tennessee_99.drop(0)
tennessee
# Out:
#     STCOU      State      County Quality of Life Population Life Expectancy  \
# 1   47000  Tennessee         NaN             NaN    6886834       75.328809
# 2   47001  Tennessee    Anderson       -0.094491      77558       74.660459
# 3   47003  Tennessee     Bedford       -0.027905      50179        74.09879
# 4   47005  Tennessee      Benton           0.142      16131       72.033756
# 5   47007  Tennessee     Bledsoe        0.140049      15223        77.40541
# ..    ...        ...         ...             ...        ...             ...
# 92  47181  Tennessee       Wayne        0.106037      16524       75.266324
# 93  47183  Tennessee     Weakley       -0.388549      33334       75.311017
# 94  47185  Tennessee       White        0.028249      27707       74.484976
# 95  47187  Tennessee  Williamson       -1.676745     245348       81.513946
# 96  47189  Tennessee      Wilson       -0.760349     148130       77.542994
#
# ...

# %%
texas_subrank = pd.read_excel('2022 County Health Rankings Texas Data - v1.xlsx', 2)
texas_data = pd.read_excel('2022 County Health Rankings Texas Data - v1.xlsx', 3)
texas_data2 = pd.read_excel('2022 County Health Rankings Texas Data - v1.xlsx', 4)

# %%
new_texas_subrank = texas_subrank[['Unnamed: 0','Unnamed: 1','Unnamed: 2','Quality of Life']]
new_texas_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
texas_combined = texas_data[['Unnamed: 1', 'Unnamed: 2','Unnamed: 155','Adult obesity','Access to exercise opportunities']]
texas_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
new_texas = texas_data2[['Unnamed: 1', 'Unnamed: 2', 'Population', 'Life expectancy','Median household income']]
new_texas.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Population':'Population', 'Life expectancy':'Life Expectancy', 'Median household income':'Median Household Income'}, inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\2493709765.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_texas_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\2493709765.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   texas_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
# ...

# %%
texas_half = pd.merge(new_texas_subrank, new_texas)
texas_99 = pd.merge(texas_half, texas_combined)
texas = texas_99.drop(0)
texas
# Out:
#      STCOU  State    County Quality of Life Population Life Expectancy  \
# 1    48000  Texas       NaN             NaN   29360759       78.394109
# 2    48001  Texas  Anderson       -0.030041      57805       73.165774
# 3    48003  Texas   Andrews       -0.221081      18879       76.393609
# 4    48005  Texas  Angelina        0.290697      86796       75.090795
# 5    48007  Texas   Aransas        0.255289      23814       74.928827
# ..     ...    ...       ...             ...        ...             ...
# 251  48499  Texas      Wood       -0.261947      46291       76.205906
# 252  48501  Texas    Yoakum       -0.260268       8702       75.645036
# 253  48503  Texas     Young       -0.481062      17904       73.955599
# 254  48505  Texas    Zapata        0.531282      14172       77.803871
# 255  48507  Texas    Zavala        0.703061      11840       73.886628
#
#     Median Household Income Percent Some College Adult Obesity  \
# ...

# %%
utah_subrank = pd.read_excel('2022 County Health Rankings Utah Data - v1.xlsx', 2)
utah_data = pd.read_excel('2022 County Health Rankings Utah Data - v1.xlsx', 3)
utah_data2 = pd.read_excel('2022 County Health Rankings Utah Data - v1.xlsx', 4)

# %%
new_utah_subrank = utah_subrank[['Unnamed: 0','Unnamed: 1','Unnamed: 2','Quality of Life']]
new_utah_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
utah_combined = utah_data[['Unnamed: 1', 'Unnamed: 2','Unnamed: 155','Adult obesity','Access to exercise opportunities']]
utah_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
new_utah = utah_data2[['Unnamed: 1', 'Unnamed: 2', 'Population', 'Life expectancy','Median household income']]
new_utah.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Population':'Population', 'Life expectancy':'Life Expectancy', 'Median household income':'Median Household Income'}, inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\1356830921.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_utah_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\1356830921.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   utah_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
# ...

# %%
utah_half = pd.merge(new_utah_subrank, new_utah)
utah_99 = pd.merge(utah_half, utah_combined)
utah = utah_99.drop(0)
utah
# Out:
#     STCOU State      County Quality of Life Population Life Expectancy  \
# 1   49000  Utah         NaN             NaN    3249879       79.717238
# 2   49001  Utah      Beaver        0.151575       6761       78.493493
# 3   49003  Utah   Box Elder       -0.085197      57007       78.763827
# 4   49005  Utah       Cache       -0.257755     130004       81.271397
# 5   49007  Utah      Carbon        0.649537      20760       75.614803
# 6   49009  Utah     Daggett             NaN       1026             NaN
# 7   49011  Utah       Davis       -0.470286     359232       80.236491
# 8   49013  Utah    Duchesne        0.210131      19894        76.21183
# 9   49015  Utah       Emery       -0.085309      10147        76.66676
# 10  49017  Utah    Garfield        0.003383       5050       77.729074
# 11  49019  Utah       Grand       -0.300553       9796       79.393422
# 12  49021  Utah        Iron        0.289221      56814       79.310442
# ...

# %%
vermont_subrank = pd.read_excel('2022 County Health Rankings Vermont Data - v1.xlsx', 2)
vermont_data = pd.read_excel('2022 County Health Rankings Vermont Data - v1.xlsx', 3)
vermont_data2 = pd.read_excel('2022 County Health Rankings Vermont Data - v1.xlsx', 4)

# %%
new_vermont_subrank = vermont_subrank[['Unnamed: 0','Unnamed: 1','Unnamed: 2','Quality of Life']]
new_vermont_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
vermont_combined = vermont_data[['Unnamed: 1', 'Unnamed: 2','Unnamed: 155','Adult obesity','Access to exercise opportunities']]
vermont_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
new_vermont = vermont_data2[['Unnamed: 1', 'Unnamed: 2', 'Population', 'Life expectancy','Median household income']]
new_vermont.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Population':'Population', 'Life expectancy':'Life Expectancy', 'Median household income':'Median Household Income'}, inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\3363112582.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_vermont_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\3363112582.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vermont_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
# ...

# %%
vermont_half = pd.merge(new_vermont_subrank, new_vermont)
vermont_99 = pd.merge(vermont_half, vermont_combined)
vermont = vermont_99.drop(0)
vermont
# Out:
#     STCOU    State      County Quality of Life Population Life Expectancy  \
# 1   50000  Vermont         NaN             NaN     623347       79.673415
# 2   50001  Vermont     Addison       -0.440005      36851       81.344859
# 3   50003  Vermont  Bennington        0.386722      35338        77.72194
# 4   50005  Vermont   Caledonia        0.260101      29705       78.403966
# 5   50007  Vermont  Chittenden       -0.536684     164306       81.721401
# 6   50009  Vermont       Essex         0.19601       6123       79.801557
# 7   50011  Vermont    Franklin       -0.009042      49685       78.789052
# 8   50013  Vermont  Grand Isle       -0.517742       7169       80.490816
# 9   50015  Vermont    Lamoille       -0.217867      25341       80.361833
# 10  50017  Vermont      Orange        0.268037      28837       79.822668
# 11  50019  Vermont     Orleans        0.633342      26897       77.941831
# 12  50021  Vermont     Rutland        0.084697      57764        77.21817
# ...

# %%
virginia_subrank = pd.read_excel('2022 County Health Rankings Virginia Data - v1.xlsx', 2)
virginia_data = pd.read_excel('2022 County Health Rankings Virginia Data - v1.xlsx', 3)
virginia_data2 = pd.read_excel('2022 County Health Rankings Virginia Data - v1.xlsx', 4)

# %%
new_virginia_subrank = virginia_subrank[['Unnamed: 0','Unnamed: 1','Unnamed: 2','Quality of Life']]
new_virginia_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
virginia_combined = virginia_data[['Unnamed: 1', 'Unnamed: 2','Unnamed: 155','Adult obesity','Access to exercise opportunities']]
virginia_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
new_virginia = virginia_data2[['Unnamed: 1', 'Unnamed: 2', 'Population', 'Life expectancy','Median household income']]
new_virginia.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Population':'Population', 'Life expectancy':'Life Expectancy', 'Median household income':'Median Household Income'}, inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\1202796158.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_virginia_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\1202796158.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   virginia_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
# ...

# %%
virginia_half = pd.merge(new_virginia_subrank, new_virginia)
virginia_99 = pd.merge(virginia_half, virginia_combined)
virginia = virginia_99.drop(0)
virginia
# Out:
#      STCOU     State               County Quality of Life Population  \
# 1    51000  Virginia                  NaN             NaN    8590563
# 2    51001  Virginia             Accomack        0.395506      32238
# 3    51003  Virginia            Albemarle       -0.657005     110652
# 4    51005  Virginia            Alleghany        0.165697      14701
# 5    51007  Virginia               Amelia       -0.092701      13014
# ..     ...       ...                  ...             ...        ...
# 130  51800  Virginia         Suffolk City       -0.078065      93913
# 131  51810  Virginia  Virginia Beach City       -0.393688     451231
# 132  51820  Virginia      Waynesboro City        0.098481      22741
# 133  51830  Virginia    Williamsburg City       -0.439904      15259
# 134  51840  Virginia      Winchester City       -0.064209      27700
#
#     Life Expectancy Median Household Income Percent Some College  \
# 1         79.066032                   79154            71.800204
# ...

# %%
washington_subrank = pd.read_excel('2022 County Health Rankings Washington Data - v1.xlsx', 2)
washington_data = pd.read_excel('2022 County Health Rankings Washington Data - v1.xlsx', 3)
washington_data2 = pd.read_excel('2022 County Health Rankings Washington Data - v1.xlsx', 4)

# %%
new_washington_subrank = washington_subrank[['Unnamed: 0','Unnamed: 1','Unnamed: 2','Quality of Life']]
new_washington_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
washington_combined = washington_data[['Unnamed: 1', 'Unnamed: 2','Unnamed: 155','Adult obesity','Access to exercise opportunities']]
washington_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
new_washington = washington_data2[['Unnamed: 1', 'Unnamed: 2', 'Population', 'Life expectancy','Median household income']]
new_washington.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Population':'Population', 'Life expectancy':'Life Expectancy', 'Median household income':'Median Household Income'}, inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\1592469028.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_washington_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\1592469028.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   washington_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
# ...

# %%
washington_half = pd.merge(new_washington_subrank, new_washington)
washington_99 = pd.merge(washington_half, washington_combined)
washington = washington_99.drop(0)
washington
# Out:
#     STCOU       State        County Quality of Life Population  \
# 1   53000  Washington           NaN             NaN    7693612
# 2   53001  Washington         Adams        0.666247      20027
# 3   53003  Washington        Asotin        0.134266      22820
# 4   53005  Washington        Benton       -0.179994     206426
# 5   53007  Washington        Chelan       -0.077317      77574
# 6   53009  Washington       Clallam        0.010132      78067
# 7   53011  Washington         Clark       -0.249632     496865
# 8   53013  Washington      Columbia        0.631644       4048
# 9   53015  Washington       Cowlitz        0.128216     111371
# 10  53017  Washington       Douglas       -0.054378      43560
# 11  53019  Washington         Ferry        0.575278       7759
# 12  53021  Washington      Franklin         0.12035      97075
# 13  53023  Washington      Garfield        0.371817       2290
# 14  53025  Washington         Grant        0.230183      99377
# ...

# %%
westvirginia_subrank = pd.read_excel('2022 County Health Rankings West Virginia Data - v1.xlsx', 2)
westvirginia_data = pd.read_excel('2022 County Health Rankings West Virginia Data - v1.xlsx', 3)
westvirginia_data2 = pd.read_excel('2022 County Health Rankings West Virginia Data - v1.xlsx', 4)

# %%
new_westvirginia_subrank = westvirginia_subrank[['Unnamed: 0','Unnamed: 1','Unnamed: 2','Quality of Life']]
new_westvirginia_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
westvirginia_combined = westvirginia_data[['Unnamed: 1', 'Unnamed: 2','Unnamed: 155','Adult obesity','Access to exercise opportunities']]
westvirginia_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
new_westvirginia = westvirginia_data2[['Unnamed: 1', 'Unnamed: 2', 'Population', 'Life expectancy','Median household income']]
new_westvirginia.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Population':'Population', 'Life expectancy':'Life Expectancy', 'Median household income':'Median Household Income'}, inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\367486102.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_westvirginia_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\367486102.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   westvirginia_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
# ...

# %%
westvirginia_half = pd.merge(new_westvirginia_subrank, new_westvirginia)
westvirginia_99 = pd.merge(westvirginia_half, westvirginia_combined)
westvirginia = westvirginia_99.drop(0)
westvirginia
# Out:
#     STCOU          State      County Quality of Life Population  \
# 1   54000  West Virginia         NaN             NaN    1784787
# 2   54001  West Virginia     Barbour       -0.178447      16444
# 3   54003  West Virginia    Berkeley       -0.548836     122125
# 4   54005  West Virginia       Boone        0.717353      21055
# 5   54007  West Virginia     Braxton        0.248157      13702
# 6   54009  West Virginia      Brooke       -0.406799      21674
# 7   54011  West Virginia      Cabell        0.138884      91589
# 8   54013  West Virginia     Calhoun        0.400459       6945
# 9   54015  West Virginia        Clay        0.378365       8341
# 10  54017  West Virginia   Doddridge       -0.195424       8368
# 11  54019  West Virginia     Fayette        0.212798      42062
# 12  54021  West Virginia      Gilmer       -0.545695       7811
# 13  54023  West Virginia       Grant        0.013988      11510
# 14  54025  West Virginia  Greenbrier       -0.125581      34319
# ...

# %%
wisconsin_subrank = pd.read_excel('2022 County Health Rankings Wisconsin Data - v1.xlsx', 2)
wisconsin_data = pd.read_excel('2022 County Health Rankings Wisconsin Data - v1.xlsx', 3)
wisconsin_data2 = pd.read_excel('2022 County Health Rankings Wisconsin Data - v1.xlsx', 4)

# %%
new_wisconsin_subrank = wisconsin_subrank[['Unnamed: 0','Unnamed: 1','Unnamed: 2','Quality of Life']]
new_wisconsin_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
wisconsin_combined = wisconsin_data[['Unnamed: 1', 'Unnamed: 2','Unnamed: 155','Adult obesity','Access to exercise opportunities']]
wisconsin_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
new_wisconsin = wisconsin_data2[['Unnamed: 1', 'Unnamed: 2', 'Population', 'Life expectancy','Median household income']]
new_wisconsin.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Population':'Population', 'Life expectancy':'Life Expectancy', 'Median household income':'Median Household Income'}, inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\397703690.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_wisconsin_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\397703690.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wisconsin_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
# ...

# %%
wisconsin_half = pd.merge(new_wisconsin_subrank, new_wisconsin)
wisconsin_99 = pd.merge(wisconsin_half, wisconsin_combined)
wisconsin = wisconsin_99.drop(0)
wisconsin
# Out:
#     STCOU      State     County Quality of Life Population Life Expectancy  \
# 1   55000  Wisconsin        NaN             NaN    5832655       78.868517
# 2   55001  Wisconsin      Adams        0.516768      20498       76.882304
# 3   55003  Wisconsin    Ashland        0.368311      15415         75.7875
# 4   55005  Wisconsin     Barron       -0.023295      45090       78.486159
# 5   55007  Wisconsin   Bayfield       -0.350954      15242       79.696285
# ..    ...        ...        ...             ...        ...             ...
# 69  55133  Wisconsin   Waukesha       -0.738489     406172       81.095703
# 70  55135  Wisconsin    Waupaca       -0.107245      50664       77.127021
# 71  55137  Wisconsin   Waushara        0.228589      24326       79.133681
# 72  55139  Wisconsin  Winnebago       -0.027305     171631       79.075133
# 73  55141  Wisconsin       Wood        0.062983      72560       78.223786
#
#    Median Household Income Percent Some College Adult Obesity  \
# ...

# %%
wyoming_subrank = pd.read_excel('2022 County Health Rankings Wyoming Data - v1.xlsx', 2)
wyoming_data = pd.read_excel('2022 County Health Rankings Wyoming Data - v1.xlsx', 3)
wyoming_data2 = pd.read_excel('2022 County Health Rankings Wyoming Data - v1.xlsx', 4)

# %%
new_wyoming_subrank = wyoming_subrank[['Unnamed: 0','Unnamed: 1','Unnamed: 2','Quality of Life']]
new_wyoming_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
wyoming_combined = wyoming_data[['Unnamed: 1', 'Unnamed: 2','Unnamed: 155','Adult obesity','Access to exercise opportunities']]
wyoming_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
new_wyoming = wyoming_data2[['Unnamed: 1', 'Unnamed: 2', 'Population', 'Life expectancy','Median household income']]
new_wyoming.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Population':'Population', 'Life expectancy':'Life Expectancy', 'Median household income':'Median Household Income'}, inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\1326731830.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_wyoming_subrank.rename(columns = {'Unnamed: 0':'STCOU','Unnamed: 1':'State', 'Unnamed: 2':'County'}, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_20140\1326731830.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wyoming_combined.rename(columns = {'Unnamed: 1':'State', 'Unnamed: 2':'County', 'Unnamed: 155':'Percent Some College','Adult obesity':'Adult Obesity','Access to exercise opportunities':' Percent Exercise'}, inplace = True)
# ...

# %%
wyoming_half = pd.merge(new_wyoming_subrank, new_wyoming)
wyoming_99 = pd.merge(wyoming_half, wyoming_combined)
wyoming = wyoming_99.drop(0)
wyoming
# Out:
#     STCOU    State       County Quality of Life Population Life Expectancy  \
# 1   56000  Wyoming          NaN             NaN     582328       78.083662
# 2   56001  Wyoming       Albany        -0.01187      38950       80.779392
# 3   56003  Wyoming     Big Horn        0.053413      11575       76.436483
# 4   56005  Wyoming     Campbell        0.305343      46676       77.443823
# 5   56007  Wyoming       Carbon        0.470491      14711       78.491099
# 6   56009  Wyoming     Converse        0.197008      13804       79.102088
# 7   56011  Wyoming        Crook       -0.131795       7593       78.782302
# 8   56013  Wyoming      Fremont        0.341674      39317       73.027828
# 9   56015  Wyoming       Goshen       -0.072094      13235       77.884951
# 10  56017  Wyoming  Hot Springs        0.045245       4425        72.29892
# 11  56019  Wyoming      Johnson       -0.231616       8588       79.900213
# ...

# %%
lllll. alas = pd.DataFrame(alaska). hawa = pd.DataFrame(hawaii). PACIFIC = pd.concat([alas, cali, hawa, oreg, wash])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20140\123324764.py in <module>
# ----> 1 lllll. alas = pd.DataFrame(alaska). hawa = pd.DataFrame(hawaii). PACIFIC = pd.concat([alas, cali, hawa, oreg, wash])
#
# NameError: name 'alas' is not defined

# %%
wash = pd.DataFrame(washington)
oreg = pd.DataFrame(oregon)
cali = pd.DataFrame(california)
PACIFIC = pd.concat([cali, oreg, wash])
PACIFIC

# %%
mont = pd.DataFrame(montana)
wyom = pd.DataFrame(wyoming)
colo = pd.DataFrame(colorado)
uta = pd.DataFrame(utah)
idah = pd.DataFrame(idaho)
neva = pd.DataFrame(nevada)
ROCKIES = pd.concat([colo, idah, mont, neva, uta, wyom])
ROCKIES

# %%
ariz = pd.DataFrame(arizona)
newm = pd.DataFrame(newmexico)
okla = pd.DataFrame(oklahoma)
texa = pd.DataFrame(texas)
SOUTHWEST = pd.concat([ariz, newm, okla, texa])
SOUTHWEST

# %%
illi = pd.DataFrame(illinois)
indi = pd.DataFrame(indiana)
iow = pd.DataFrame(iowa)
kans = pd.DataFrame(kansas)
mich = pd.DataFrame(michigan)
minn = pd.DataFrame(minnesota)
misso = pd.DataFrame(missouri)
nebr = pd.DataFrame(nebraska)
northd = pd.DataFrame(northdakota)
ohi = pd.DataFrame(ohio)
southd = pd.DataFrame(southdakota)
wisc = pd.DataFrame(wisconsin)
MIDWEST = pd.concat([illi, indi, iow, kans, mich, minn, misso, nebr, northd, ohi, southd, wisc])
MIDWEST

# %%
alab = pd.DataFrame(alabama)
arka = pd.DataFrame(arkansas)
flor = pd.DataFrame(florida)
geor = pd.DataFrame(georgia)
kent = pd.DataFrame(kentucky)
loui = pd.DataFrame(louisiana)
missi = pd.DataFrame(mississippi)
northc = pd.DataFrame(northcarolina)
southc = pd.DataFrame(southcarolina)
tenn = pd.DataFrame(tennessee)
virg = pd.DataFrame(virginia)
west = pd.DataFrame(westvirginia)
SOUTHEAST = pd.concat([alab, arka, flor, geor, kent, loui, missi, northc, southc, tenn, virg, west])
SOUTHEAST

# %%
dela = pd.DataFrame(delaware)
mary = pd.DataFrame(maryland)
newj = pd.DataFrame(newjersey)
newy = pd.DataFrame(newyork)
penn = pd.DataFrame(pennsylvania)
MIDATLANTIC = pd.concat([dela, mary, newj, newy, penn])
MIDATLANTIC

# %%
conn = pd.DataFrame(connecticut)
main = pd.DataFrame(maine)
mass = pd.DataFrame(massachusetts)
newh = pd.DataFrame(newhampshire)
rhod = pd.DataFrame(rhodeisland)
verm = pd.DataFrame(vermont)
NORTHEAST = pd.concat([conn, main, mass, newh, rhod, verm])
NORTHEAST

# %%
PACI = pd.DataFrame(PACIFIC)
ROCK = pd.DataFrame(ROCKIES)
SOUTHW = pd.DataFrame(SOUTHWEST)
MIDW = pd.DataFrame(MIDWEST)
SOUTHE = pd.DataFrame(SOUTHEAST)
MIDA = pd.DataFrame(MIDATLANTIC)
NORT = pd.DataFrame(NORTHEAST)
USA_FULL = pd.concat([PACI, ROCK, SOUTHW, MIDW, SOUTHE, MIDA, NORT])
USA_FULL

# %%
sort_usa = USA_FULL.sort_values(['State','County'])
sort_usa

# %%
sort_county=USA_FULL.sort_values('County')
sort_county.tail(50)

# %%
new_counties = sort_county.reset_index(drop=True)
new_counties.tail(51)

# %%
counties2 = new_counties.drop([3107, 3108, 3109, 3110, 3111, 3112, 3113, 3114, 3115, 3116, 3117, 3118, 3119, 3120, 3121, 3122, 3123, 3124, 3125, 3126, 3127, 3128, 3128, 3129, 3130, 3131, 3132, 3133, 3134, 3135, 3136, 3137, 3138, 3139, 3140, 3141, 3142, 3143, 3144, 3145, 3146, 3147, 3148, 3149, 3150, 3151, 3152, 3153, 3154])
counties2

# %%
counties2.index = np.arange(1, len(counties2) + 1)
counties2

# %%
COUNTIES99 = counties2.sort_values(['State','County'])
COUNTIES99

# %%
COUNTIES = COUNTIES99.reset_index(drop=True)
COUNTIES.index = np.arange(1, len(COUNTIES) + 1)
COUNTIES

# %%
COUNTIES.to_csv('../data/usa_counties_contiguous.csv')

# %%
all50 = sort_county.tail(50)
all50

# %%
states_area = pd.read_csv('STATES_AREA_FIXED.csv')
states_area.head()

# %%
STATES = all50.sort_values('State')
STATES

# %%
STATES['State'] = STATES['State'].str.upper()
STATES

# %%
STATES_FULLISH = pd.merge(STATES, states_area, on = ['State', 'County'], how = "inner")
STATES_FULLISH

# %%
STATES_FULLISH.drop('Unnamed: 0', inplace=True, axis=1)
STATES_FULLISH

# %%
STATES_FULLISH['Density'] = STATES_FULLISH['Population'] / STATES_FULLISH['sq_miles']
STATES_FULLISH

# %%
STATES_FULLISH.describe()

# %%
top_QOL_county = COUNTIES.sort_values("Quality of Life", axis=0, ascending=True)
top_QOL_county

# %%
bottom_QOL_county = COUNTIES.sort_values("Quality of Life", axis=0, ascending=False)
bottom_QOL_county

# %%
low_POP_county = COUNTIES.sort_values("Population", axis=0, ascending=True)
low_POP_county

# %%
high_POP_county = COUNTIES.sort_values("Population", axis=0, ascending=False)
high_POP_county

# %%
AVG = COUNTIES.mean()
AVG

# %%
top_LIFE_county = COUNTIES.sort_values("Life Expectancy", axis=0, ascending=False)
top_LIFE_county

# %%
bottom_LIFE_county = COUNTIES.sort_values("Life Expectancy", axis=0, ascending=True)
bottom_LIFE_county

# %%
top_MHI_county = COUNTIES.sort_values("Median Household Income", axis=0, ascending=False)
top_MHI_county

# %%
bottom_MHI_county = COUNTIES.sort_values("Median Household Income", axis=0, ascending=True)
bottom_MHI_county

# %%
top_PSC_county = COUNTIES.sort_values("Percent Some College", axis=0, ascending=False)
top_PSC_county

# %%
bottom_PSC_county = COUNTIES.sort_values("Percent Some College", axis=0, ascending=True)
bottom_PSC_county

# %%
high_AO_county = COUNTIES.sort_values("Adult Obesity", axis=0, ascending=False)
high_AO_county

# %%
low_AO_county = COUNTIES.sort_values("Adult Obesity", axis=0, ascending=True)
low_AO_county

# %%
COUNTIES

# %%
geo = pd.read_csv("../data/geometry_counties.csv")
geo

# %%
geo.rename(columns = {'Unnamed: 0':'Number', 'NAME':'County', 'STATE_NAME' : 'State'}, inplace = True)
geo

# %%
geo.drop('Number', inplace=True, axis=1)
geo

# %%
work = pd.merge(COUNTIES, geo, on = ["County",'State'], how = "inner")

# %%
work

# %%
work.to_csv('../data/countiesgeo.csv')
